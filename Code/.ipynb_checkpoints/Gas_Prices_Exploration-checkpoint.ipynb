# %%
import json
import requests
from config import api_key
import datetime
import pandas as pd
import os
import getpass as gp
import pymongo

# %%
from pprint import pprint

# %% [markdown]
# # Main API

# %% [markdown]
# ### EIA Data Sets > Petroleum > Prices > Weekly Retail Gasoline and Diesel Prices > by Area > California

# %%
#https://www.eia.gov/opendata/qb.php?category=240839

# Establishes my URL string
url_cali = 'http://api.eia.gov/category/?api_key=YOUR_API_KEY_HERE&category_id=240839'

# Inserts my API key
url_new_cali = url_cali.replace('YOUR_API_KEY_HERE', api_key)

# %%
# Converts to json
api_response = requests.get(url_new_cali)
api_json_cali = api_response.json()

# %%
# pprint(api_json_cali)

# %% [markdown]
# # Annual API

# %% [markdown]
# ### EIA Data Sets > Petroleum > Prices > Weekly Retail Gasoline and Diesel Prices > by Area > California > Annual

# %%
# https://www.eia.gov/opendata/qb.php?category=240839&sdid=PET.EMM_EPM0_PTE_SCA_DPG.A

# Establishes my URL string
url_annual = 'http://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=PET.EMM_EPM0_PTE_SCA_DPG.A'

# Inserts my API key
url_new_annual = url_annual.replace('YOUR_API_KEY_HERE', api_key)

# %%
# Converts to json
api_response = requests.get(url_new_annual)
api_json_annual = api_response.json()

# %%
# pprint(api_json_annual)

# %%
# Navigates to key: series
api_json_series_a = api_json_annual['series']

# changes list back to dictionary
api_json_series_a = api_json_series_a[0]

# Navigates to key: data
api_json_data_a = api_json_series_a['data']

# %%
# api_json_data_a

# %%
# iterates through list prep for data frame
yearly_list = [['Year', 'CA Avg']]
for i in api_json_data_a:
    yearly_list.append([i[0], i[1]])

# Creates DataFrame
annual_df = pd.DataFrame(yearly_list[1:],columns=yearly_list[0])

# Drops Nan rows
annual_df = annual_df.dropna()


file_path = '..\Output\Annual_Prices.csv'


annual_df.to_csv(file_path, index=False)

# %%
annual_df
# Out:
#     Year  CA Avg
# 0   2019   3.677
# 1   2018   3.551
# 2   2017   3.080
# 3   2016   2.782
# 4   2015   3.221
# 5   2014   3.794
# 6   2013   3.933
# 7   2012   4.081
# 8   2011   3.863
# 9   2010   3.138
# 10  2009   2.725
# 11  2008   3.561
# 12  2007   3.124
# 13  2006   2.855
# 14  2005   2.517
# 15  2004   2.166
# 16  2003   1.878
# 17  2002   1.561
# 18  2001   1.677

# %% [markdown]
# # Monthly API

# %% [markdown]
# ### EIA Data Sets > Petroleum > Prices > Weekly Retail Gasoline and Diesel Prices > by Area > California > Monthly

# %%
# https://www.eia.gov/opendata/qb.php?category=240839&sdid=PET.EMM_EPM0_PTE_SCA_DPG.A

# Establishes my URL string
url_month = 'http://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=PET.EMM_EPM0_PTE_SCA_DPG.M'

# Inserts my API key
url_new_month = url_month.replace('YOUR_API_KEY_HERE', api_key)

# %%
# Converts to json
api_response = requests.get(url_new_month)
api_json_month = api_response.json()

# %%
# pprint(api_json_month)

# %%
# Navigates to key: series
api_json_series_m = api_json_month['series']

# changes list back to dictionary
api_json_series_m = api_json_series_m[0]

# Navigates to key: data
api_json_data_m = api_json_series_m['data']

# %%
# api_json_data_m

# %%
# Preps a list for iteration
dates_list_m = [['Year', 'Month', 'CA Avg']]

# Iterates through list and parses the date into separate year, month rows
for i in api_json_data_m:
    long_date = i[0]
    parsed_date = datetime.datetime.strptime(long_date, '%Y%m')
    year = parsed_date.date().year
    month = parsed_date.date().month
    dates_list_m.append([year, month, i[1]])

# Creates dataframe from list
monthly_df = pd.DataFrame(dates_list_m[1:],columns=dates_list_m[0])


file_path = '..\Output\Monthly_Prices.csv'


monthly_df.to_csv(file_path, index=False)

# %%
monthly_df
# Out:
#      Year  Month  CA Avg
# 0    2020      3   3.262
# 1    2020      2   3.447
# 2    2020      1   3.489
# 3    2019     12   3.610
# 4    2019     11   3.944
# ..    ...    ...     ...
# 234  2000      9   1.869
# 235  2000      8   1.720
# 236  2000      7   1.754
# 237  2000      6   1.669
# 238  2000      5     NaN
#
# [239 rows x 3 columns]

# %% [markdown]
# # Weekly API

# %% [markdown]
# ### EIA Data Sets > Petroleum > Prices > Weekly Retail Gasoline and Diesel Prices > by Area > California > Weekly

# %%
# https://www.eia.gov/opendata/qb.php?category=240839&sdid=PET.EMM_EPM0_PTE_SCA_DPG.A

# Establishes my URL string
url_week = 'http://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=PET.EMM_EPM0_PTE_SCA_DPG.W'

# Inserts my API key
url_new_week = url_week.replace('YOUR_API_KEY_HERE', api_key)

# %%
# Converts to json
api_response = requests.get(url_new_week)
api_json_week = api_response.json()

# %%
# pprint(api_json_week)

# %%
api_json_series_w = api_json_week['series']
api_json_series_w = api_json_series_w[0]
api_json_data_w = api_json_series_w['data']

# %%
# api_json_data_w

# %%
# Preps a list for iteration
dates_list_w = [['Year', 'Month', 'Day', 'CA Avg']]

# Iterates through list and parses the date into separate year, month rows
for i in api_json_data_w:
        long_date = i[0]
        parsed_date = datetime.datetime.strptime(long_date, '%Y%m%d')
        year = parsed_date.date().year
        month = parsed_date.date().month
        day = parsed_date.date().day
        dates_list_w.append([year, month, day, i[1]])
        
# Creates dataframe from list
weekly_df = pd.DataFrame(dates_list_w[1:],columns=dates_list_w[0])


file_path = os.path.join('..', 'Output', 'CA_Weekly_Prices.csv')


weekly_df.to_csv(file_path, index=False)

# %%
# weekly_df.head(10)

# %% [markdown]
# # CSV File

# %% [markdown]
# ### Weekly Prices - US

# %%
csv_file = os.path.join('..', 'Resources', 'Data.World', 'u_s_all_grades_all_formulations_retail_gasoline_prices_weekly.csv')

# %%
csv_file
# Out:
# '..\\Resources\\Data.World\\u_s_all_grades_all_formulations_retail_gasoline_prices_weekly.csv'

# %%
gas_csv = pd.read_csv(csv_file)

# %%
gas_list = gas_csv.values.tolist()

# %%
# gas_list

# %%
dates_list_w2 = [['Year', 'Month', 'Day', 'US Avg']]

for i in gas_list:
    long_date = i[0]
    parsed_date = datetime.datetime.strptime(long_date, '%Y-%m-%d')
    year = parsed_date.date().year
    month = parsed_date.date().month
    day = parsed_date.date().day
    price = round(i[1], 3)
    dates_list_w2.append([year, month, day, price])

                          
weekly2_df = pd.DataFrame(dates_list_w2[1:],columns=dates_list_w2[0])


file_path = os.path.join('..', 'Output', 'US_Weekly_Prices.csv')


weekly2_df.to_csv(file_path, index=False)

# %%
weekly2_df
# Out:
#       Year  Month  Day  US Avg
# 0     2020      3    9   2.468
# 1     2020      3    2   2.514
# 2     2020      2   24   2.555
# 3     2020      2   17   2.518
# 4     2020      2   10   2.511
# ...    ...    ...  ...     ...
# 1401  1993      5    3   1.086
# 1402  1993      4   26   1.086
# 1403  1993      4   19   1.079
# 1404  1993      4   12   1.079
# 1405  1993      4    5     NaN
#
# [1406 rows x 4 columns]

# %% [markdown]
# # Weekly CA prices with CA Prices

# %% [markdown]
# ### Merged Data for average Prices

# %%
All_Weekly_Prices = pd.merge(weekly_df, weekly2_df, how='inner', on=['Year', 'Month', 'Day'])

# %%
All_Weekly_Prices
# Out:
#       Year  Month  Day  CA Avg  US Avg
# 0     2020      3    9   3.403   2.468
# 1     2020      3    2   3.435   2.514
# 2     2020      2   24   3.443   2.555
# 3     2020      2   17   3.441   2.518
# 4     2020      2   10   3.449   2.511
# ...    ...    ...  ...     ...     ...
# 1029  2000      6   19   1.664   1.711
# 1030  2000      6   12   1.662   1.664
# 1031  2000      6    5   1.661   1.599
# 1032  2000      5   29   1.673   1.579
# 1033  2000      5   22   1.679   1.566
#
# [1034 rows x 5 columns]

# %%
file_path = os.path.join('..', 'Output', 'Merged_Weekly_Prices.csv')


All_Weekly_Prices.to_csv(file_path, index=False)

# %% [markdown]
# # Load into DB

# %% [markdown]
# ### Using pymongo to create db's

# %% [markdown]
# #### Create the Connection, database, and collections

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

mydb = client.Gas_Prices_DB
annual_col = mydb.Annual_Prices
monthly_col = mydb.Monthly_Prices
weekly_col = mydb.Weekly_Prices
weekly2_col = mydb.Weekly2_Prices

# %% [markdown]
# #### Convert df's to lists. One for headers and one for values.

# %%
# annual_df
# monthly_df
# weekly_df
# weekly2_df

annual_headers = annual_df.columns.values.tolist()

annual_list = annual_df.values.tolist()

# -------------------------------------------------

monthly_headers = monthly_df.columns.values.tolist()

monthly_list = monthly_df.values.tolist()

# -------------------------------------------------

weekly_headers = weekly_df.columns.values.tolist()

weekly_list = weekly_df.values.tolist()

# -------------------------------------------------

weekly2_headers = weekly2_df.columns.values.tolist()

weekly2_list = weekly2_df.values.tolist()

# %% [markdown]
# ####

# %%
for i in annual_list:
    post = {
        annual_headers[0] : i[0],
        annual_headers[1] : i[1]
    }
    annual_col.insert_one(post)
    
    
    
for i in monthly_list:
    post = {
        monthly_headers[0] : round(i[0]),
        monthly_headers[1] : round(i[1]),
        monthly_headers[2] : i[2]
    }
    monthly_col.insert_one(post)
    
    

for i in weekly_list:
    post = {
        weekly_headers[0] : round(i[0]),
        weekly_headers[1] : round(i[1]),
        weekly_headers[2] : round(i[2]),
        weekly_headers[3] : i[3]
    }
    weekly_col.insert_one(post)
    
    

for i in weekly2_list:
    post = {
        weekly2_headers[0] : round(i[0]),
        weekly2_headers[1] : round(i[1]),
        weekly2_headers[2] : round(i[2]),
        weekly2_headers[3] : i[3]
    }
    weekly2_col.insert_one(post)

# %%
results = weekly2_col.find()

for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5e852fe3783b5294fa615fbf'), 'Year': 2020, 'Month': 3, 'Day': 9, 'US Avg': 2.468}
# {'_id': ObjectId('5e852fe3783b5294fa615fc0'), 'Year': 2020, 'Month': 3, 'Day': 2, 'US Avg': 2.514}
# {'_id': ObjectId('5e852fe3783b5294fa615fc1'), 'Year': 2020, 'Month': 2, 'Day': 24, 'US Avg': 2.555}
# {'_id': ObjectId('5e852fe3783b5294fa615fc2'), 'Year': 2020, 'Month': 2, 'Day': 17, 'US Avg': 2.518}
# {'_id': ObjectId('5e852fe3783b5294fa615fc3'), 'Year': 2020, 'Month': 2, 'Day': 10, 'US Avg': 2.511}
# {'_id': ObjectId('5e852fe3783b5294fa615fc4'), 'Year': 2020, 'Month': 2, 'Day': 3, 'US Avg': 2.546}
# {'_id': ObjectId('5e852fe3783b5294fa615fc5'), 'Year': 2020, 'Month': 1, 'Day': 27, 'US Avg': 2.595}
# {'_id': ObjectId('5e852fe3783b5294fa615fc6'), 'Year': 2020, 'Month': 1, 'Day': 20, 'US Avg': 2.625}
# {'_id': ObjectId('5e852fe3783b5294fa615fc7'), 'Year': 2020, 'Month': 1, 'Day': 13, 'US Avg': 2.657}
# {'_id': ObjectId('5e852fe3783b5294fa615fc8'), 'Year': 2020, 'Month': 1, 'Day': 6, 'US Avg': 2.665}
# {'_id': ObjectId('5e852fe3783b5294fa615fc9'), 'Year': 2019, 'Month': 12, 'Day': 30, 'US Avg': 2.658}
# {'_id': ObjectId('5e852fe3783b5294fa615fca'), 'Year': 2019, 'Month': 12, 'Day': 23, 'US Avg': 2.621}
# {'_id': ObjectId('5e852fe3783b5294fa615fcb'), 'Year': 2019, 'Month': 12, 'Day': 16, 'US Avg': 2.627}
# {'_id': ObjectId('5e852fe3783b5294fa615fcc'), 'Year': 2019, 'Month': 12, 'Day': 9, 'US Avg': 2.652}
# {'_id': ObjectId('5e852fe3783b5294fa615fcd'), 'Year': 2019, 'Month': 12, 'Day': 2, 'US Avg': 2.667}
# {'_id': ObjectId('5e852fe3783b5294fa615fce'), 'Year': 2019, 'Month': 11, 'Day': 25, 'US Avg': 2.672}
# {'_id': ObjectId('5e852fe3783b5294fa615fcf'), 'Year': 2019, 'Month': 11, 'Day': 18, 'US Avg': 2.688}
# {'_id': ObjectId('5e852fe3783b5294fa615fd0'), 'Year': 2019, 'Month': 11, 'Day': 11, 'US Avg': 2.711}
# {'_id': ObjectId('5e852fe3783b5294fa615fd1'), 'Year': 2019, 'Month': 11, 'Day': 4, 'US Avg': 2.702}
# {'_id': ObjectId('5e852fe3783b5294fa615fd2'), 'Year': 2019, 'Month': 10, 'Day': 28, 'US Avg': 2.692}
# {'_id': ObjectId('5e852fe3783b5294fa615fd3'), 'Year': 2019, 'Month': 10, 'Day': 21, 'US Avg': 2.735}
# {'_id': ObjectId('5e852fe3783b5294fa615fd4'), 'Year': 2019, 'Month': 10, 'Day': 14, 'US Avg': 2.727}
# {'_id': ObjectId('5e852fe3783b5294fa615fd5'), 'Year': 2019, 'Month': 10, 'Day': 7, 'US Avg': 2.742}
# {'_id': ObjectId('5e852fe3783b5294fa615fd6'), 'Year': 2019, 'Month': 9, 'Day': 30, 'US Avg': 2.737}
# {'_id': ObjectId('5e852fe3783b5294fa615fd7'), 'Year': 2019, 'Month': 9, 'Day': 23, 'US Avg': 2.741}
# {'_id': ObjectId('5e852fe3783b5294fa615fd8'), 'Year': 2019, 'Month': 9, 'Day': 16, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa615fd9'), 'Year': 2019, 'Month': 9, 'Day': 9, 'US Avg': 2.638}
# {'_id': ObjectId('5e852fe3783b5294fa615fda'), 'Year': 2019, 'Month': 9, 'Day': 2, 'US Avg': 2.651}
# {'_id': ObjectId('5e852fe3783b5294fa615fdb'), 'Year': 2019, 'Month': 8, 'Day': 26, 'US Avg': 2.661}
# {'_id': ObjectId('5e852fe3783b5294fa615fdc'), 'Year': 2019, 'Month': 8, 'Day': 19, 'US Avg': 2.684}
# {'_id': ObjectId('5e852fe3783b5294fa615fdd'), 'Year': 2019, 'Month': 8, 'Day': 12, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa615fde'), 'Year': 2019, 'Month': 8, 'Day': 5, 'US Avg': 2.772}
# {'_id': ObjectId('5e852fe3783b5294fa615fdf'), 'Year': 2019, 'Month': 7, 'Day': 29, 'US Avg': 2.798}
# {'_id': ObjectId('5e852fe3783b5294fa615fe0'), 'Year': 2019, 'Month': 7, 'Day': 22, 'US Avg': 2.833}
# {'_id': ObjectId('5e852fe3783b5294fa615fe1'), 'Year': 2019, 'Month': 7, 'Day': 15, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa615fe2'), 'Year': 2019, 'Month': 7, 'Day': 8, 'US Avg': 2.827}
# {'_id': ObjectId('5e852fe3783b5294fa615fe3'), 'Year': 2019, 'Month': 7, 'Day': 1, 'US Avg': 2.798}
# {'_id': ObjectId('5e852fe3783b5294fa615fe4'), 'Year': 2019, 'Month': 6, 'Day': 24, 'US Avg': 2.741}
# {'_id': ObjectId('5e852fe3783b5294fa615fe5'), 'Year': 2019, 'Month': 6, 'Day': 17, 'US Avg': 2.759}
# {'_id': ObjectId('5e852fe3783b5294fa615fe6'), 'Year': 2019, 'Month': 6, 'Day': 10, 'US Avg': 2.821}
# {'_id': ObjectId('5e852fe3783b5294fa615fe7'), 'Year': 2019, 'Month': 6, 'Day': 3, 'US Avg': 2.893}
# {'_id': ObjectId('5e852fe3783b5294fa615fe8'), 'Year': 2019, 'Month': 5, 'Day': 27, 'US Avg': 2.909}
# {'_id': ObjectId('5e852fe3783b5294fa615fe9'), 'Year': 2019, 'Month': 5, 'Day': 20, 'US Avg': 2.939}
# {'_id': ObjectId('5e852fe3783b5294fa615fea'), 'Year': 2019, 'Month': 5, 'Day': 13, 'US Avg': 2.954}
# {'_id': ObjectId('5e852fe3783b5294fa615feb'), 'Year': 2019, 'Month': 5, 'Day': 6, 'US Avg': 2.983}
# {'_id': ObjectId('5e852fe3783b5294fa615fec'), 'Year': 2019, 'Month': 4, 'Day': 29, 'US Avg': 2.972}
# {'_id': ObjectId('5e852fe3783b5294fa615fed'), 'Year': 2019, 'Month': 4, 'Day': 22, 'US Avg': 2.926}
# {'_id': ObjectId('5e852fe3783b5294fa615fee'), 'Year': 2019, 'Month': 4, 'Day': 15, 'US Avg': 2.912}
# {'_id': ObjectId('5e852fe3783b5294fa615fef'), 'Year': 2019, 'Month': 4, 'Day': 8, 'US Avg': 2.826}
# {'_id': ObjectId('5e852fe3783b5294fa615ff0'), 'Year': 2019, 'Month': 4, 'Day': 1, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa615ff1'), 'Year': 2019, 'Month': 3, 'Day': 25, 'US Avg': 2.701}
# {'_id': ObjectId('5e852fe3783b5294fa615ff2'), 'Year': 2019, 'Month': 3, 'Day': 18, 'US Avg': 2.625}
# {'_id': ObjectId('5e852fe3783b5294fa615ff3'), 'Year': 2019, 'Month': 3, 'Day': 11, 'US Avg': 2.549}
# {'_id': ObjectId('5e852fe3783b5294fa615ff4'), 'Year': 2019, 'Month': 3, 'Day': 4, 'US Avg': 2.502}
# {'_id': ObjectId('5e852fe3783b5294fa615ff5'), 'Year': 2019, 'Month': 2, 'Day': 25, 'US Avg': 2.471}
# {'_id': ObjectId('5e852fe3783b5294fa615ff6'), 'Year': 2019, 'Month': 2, 'Day': 18, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa615ff7'), 'Year': 2019, 'Month': 2, 'Day': 11, 'US Avg': 2.361}
# {'_id': ObjectId('5e852fe3783b5294fa615ff8'), 'Year': 2019, 'Month': 2, 'Day': 4, 'US Avg': 2.341}
# {'_id': ObjectId('5e852fe3783b5294fa615ff9'), 'Year': 2019, 'Month': 1, 'Day': 28, 'US Avg': 2.343}
# {'_id': ObjectId('5e852fe3783b5294fa615ffa'), 'Year': 2019, 'Month': 1, 'Day': 21, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa615ffb'), 'Year': 2019, 'Month': 1, 'Day': 14, 'US Avg': 2.338}
# {'_id': ObjectId('5e852fe3783b5294fa615ffc'), 'Year': 2019, 'Month': 1, 'Day': 7, 'US Avg': 2.329}
# {'_id': ObjectId('5e852fe3783b5294fa615ffd'), 'Year': 2018, 'Month': 12, 'Day': 31, 'US Avg': 2.358}
# {'_id': ObjectId('5e852fe3783b5294fa615ffe'), 'Year': 2018, 'Month': 12, 'Day': 24, 'US Avg': 2.413}
# {'_id': ObjectId('5e852fe3783b5294fa615fff'), 'Year': 2018, 'Month': 12, 'Day': 17, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616000'), 'Year': 2018, 'Month': 12, 'Day': 10, 'US Avg': 2.511}
# {'_id': ObjectId('5e852fe3783b5294fa616001'), 'Year': 2018, 'Month': 12, 'Day': 3, 'US Avg': 2.544}
# {'_id': ObjectId('5e852fe3783b5294fa616002'), 'Year': 2018, 'Month': 11, 'Day': 26, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616003'), 'Year': 2018, 'Month': 11, 'Day': 19, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616004'), 'Year': 2018, 'Month': 11, 'Day': 12, 'US Avg': 2.773}
# {'_id': ObjectId('5e852fe3783b5294fa616005'), 'Year': 2018, 'Month': 11, 'Day': 5, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616006'), 'Year': 2018, 'Month': 10, 'Day': 29, 'US Avg': 2.896}
# {'_id': ObjectId('5e852fe3783b5294fa616007'), 'Year': 2018, 'Month': 10, 'Day': 22, 'US Avg': 2.925}
# {'_id': ObjectId('5e852fe3783b5294fa616008'), 'Year': 2018, 'Month': 10, 'Day': 15, 'US Avg': 2.961}
# {'_id': ObjectId('5e852fe3783b5294fa616009'), 'Year': 2018, 'Month': 10, 'Day': 8, 'US Avg': 2.984}
# {'_id': ObjectId('5e852fe3783b5294fa61600a'), 'Year': 2018, 'Month': 10, 'Day': 1, 'US Avg': 2.947}
# {'_id': ObjectId('5e852fe3783b5294fa61600b'), 'Year': 2018, 'Month': 9, 'Day': 24, 'US Avg': 2.923}
# {'_id': ObjectId('5e852fe3783b5294fa61600c'), 'Year': 2018, 'Month': 9, 'Day': 17, 'US Avg': 2.921}
# {'_id': ObjectId('5e852fe3783b5294fa61600d'), 'Year': 2018, 'Month': 9, 'Day': 10, 'US Avg': 2.912}
# {'_id': ObjectId('5e852fe3783b5294fa61600e'), 'Year': 2018, 'Month': 9, 'Day': 3, 'US Avg': 2.903}
# {'_id': ObjectId('5e852fe3783b5294fa61600f'), 'Year': 2018, 'Month': 8, 'Day': 27, 'US Avg': 2.906}
# {'_id': ObjectId('5e852fe3783b5294fa616010'), 'Year': 2018, 'Month': 8, 'Day': 20, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616011'), 'Year': 2018, 'Month': 8, 'Day': 13, 'US Avg': 2.921}
# {'_id': ObjectId('5e852fe3783b5294fa616012'), 'Year': 2018, 'Month': 8, 'Day': 6, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616013'), 'Year': 2018, 'Month': 7, 'Day': 30, 'US Avg': 2.924}
# {'_id': ObjectId('5e852fe3783b5294fa616014'), 'Year': 2018, 'Month': 7, 'Day': 23, 'US Avg': 2.911}
# {'_id': ObjectId('5e852fe3783b5294fa616015'), 'Year': 2018, 'Month': 7, 'Day': 16, 'US Avg': 2.943}
# {'_id': ObjectId('5e852fe3783b5294fa616016'), 'Year': 2018, 'Month': 7, 'Day': 9, 'US Avg': 2.937}
# {'_id': ObjectId('5e852fe3783b5294fa616017'), 'Year': 2018, 'Month': 7, 'Day': 2, 'US Avg': 2.924}
# {'_id': ObjectId('5e852fe3783b5294fa616018'), 'Year': 2018, 'Month': 6, 'Day': 25, 'US Avg': 2.913}
# {'_id': ObjectId('5e852fe3783b5294fa616019'), 'Year': 2018, 'Month': 6, 'Day': 18, 'US Avg': 2.958}
# {'_id': ObjectId('5e852fe3783b5294fa61601a'), 'Year': 2018, 'Month': 6, 'Day': 11, 'US Avg': 2.989}
# {'_id': ObjectId('5e852fe3783b5294fa61601b'), 'Year': 2018, 'Month': 6, 'Day': 4, 'US Avg': 3.018}
# {'_id': ObjectId('5e852fe3783b5294fa61601c'), 'Year': 2018, 'Month': 5, 'Day': 28, 'US Avg': 3.039}
# {'_id': ObjectId('5e852fe3783b5294fa61601d'), 'Year': 2018, 'Month': 5, 'Day': 21, 'US Avg': 2.999}
# {'_id': ObjectId('5e852fe3783b5294fa61601e'), 'Year': 2018, 'Month': 5, 'Day': 14, 'US Avg': 2.949}
# {'_id': ObjectId('5e852fe3783b5294fa61601f'), 'Year': 2018, 'Month': 5, 'Day': 7, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616020'), 'Year': 2018, 'Month': 4, 'Day': 30, 'US Avg': 2.961}
# {'_id': ObjectId('5e852fe3783b5294fa616021'), 'Year': 2018, 'Month': 4, 'Day': 23, 'US Avg': 2.914}
# {'_id': ObjectId('5e852fe3783b5294fa616022'), 'Year': 2018, 'Month': 4, 'Day': 16, 'US Avg': 2.863}
# {'_id': ObjectId('5e852fe3783b5294fa616023'), 'Year': 2018, 'Month': 4, 'Day': 9, 'US Avg': 2.811}
# {'_id': ObjectId('5e852fe3783b5294fa616024'), 'Year': 2018, 'Month': 4, 'Day': 2, 'US Avg': 2.817}
# {'_id': ObjectId('5e852fe3783b5294fa616025'), 'Year': 2018, 'Month': 3, 'Day': 26, 'US Avg': 2.764}
# {'_id': ObjectId('5e852fe3783b5294fa616026'), 'Year': 2018, 'Month': 3, 'Day': 19, 'US Avg': 2.716}
# {'_id': ObjectId('5e852fe3783b5294fa616027'), 'Year': 2018, 'Month': 3, 'Day': 12, 'US Avg': 2.677}
# {'_id': ObjectId('5e852fe3783b5294fa616028'), 'Year': 2018, 'Month': 3, 'Day': 5, 'US Avg': 2.679}
# {'_id': ObjectId('5e852fe3783b5294fa616029'), 'Year': 2018, 'Month': 2, 'Day': 26, 'US Avg': 2.666}
# {'_id': ObjectId('5e852fe3783b5294fa61602a'), 'Year': 2018, 'Month': 2, 'Day': 19, 'US Avg': 2.676}
# {'_id': ObjectId('5e852fe3783b5294fa61602b'), 'Year': 2018, 'Month': 2, 'Day': 12, 'US Avg': 2.724}
# {'_id': ObjectId('5e852fe3783b5294fa61602c'), 'Year': 2018, 'Month': 2, 'Day': 5, 'US Avg': 2.753}
# {'_id': ObjectId('5e852fe3783b5294fa61602d'), 'Year': 2018, 'Month': 1, 'Day': 29, 'US Avg': 2.723}
# {'_id': ObjectId('5e852fe3783b5294fa61602e'), 'Year': 2018, 'Month': 1, 'Day': 22, 'US Avg': 2.684}
# {'_id': ObjectId('5e852fe3783b5294fa61602f'), 'Year': 2018, 'Month': 1, 'Day': 15, 'US Avg': 2.673}
# {'_id': ObjectId('5e852fe3783b5294fa616030'), 'Year': 2018, 'Month': 1, 'Day': 8, 'US Avg': 2.639}
# {'_id': ObjectId('5e852fe3783b5294fa616031'), 'Year': 2018, 'Month': 1, 'Day': 1, 'US Avg': 2.637}
# {'_id': ObjectId('5e852fe3783b5294fa616032'), 'Year': 2017, 'Month': 12, 'Day': 25, 'US Avg': 2.589}
# {'_id': ObjectId('5e852fe3783b5294fa616033'), 'Year': 2017, 'Month': 12, 'Day': 18, 'US Avg': 2.568}
# {'_id': ObjectId('5e852fe3783b5294fa616034'), 'Year': 2017, 'Month': 12, 'Day': 11, 'US Avg': 2.601}
# {'_id': ObjectId('5e852fe3783b5294fa616035'), 'Year': 2017, 'Month': 12, 'Day': 4, 'US Avg': 2.617}
# {'_id': ObjectId('5e852fe3783b5294fa616036'), 'Year': 2017, 'Month': 11, 'Day': 27, 'US Avg': 2.648}
# {'_id': ObjectId('5e852fe3783b5294fa616037'), 'Year': 2017, 'Month': 11, 'Day': 20, 'US Avg': 2.683}
# {'_id': ObjectId('5e852fe3783b5294fa616038'), 'Year': 2017, 'Month': 11, 'Day': 13, 'US Avg': 2.706}
# {'_id': ObjectId('5e852fe3783b5294fa616039'), 'Year': 2017, 'Month': 11, 'Day': 6, 'US Avg': 2.673}
# {'_id': ObjectId('5e852fe3783b5294fa61603a'), 'Year': 2017, 'Month': 10, 'Day': 30, 'US Avg': 2.602}
# {'_id': ObjectId('5e852fe3783b5294fa61603b'), 'Year': 2017, 'Month': 10, 'Day': 23, 'US Avg': 2.594}
# {'_id': ObjectId('5e852fe3783b5294fa61603c'), 'Year': 2017, 'Month': 10, 'Day': 16, 'US Avg': 2.605}
# {'_id': ObjectId('5e852fe3783b5294fa61603d'), 'Year': 2017, 'Month': 10, 'Day': 9, 'US Avg': 2.622}
# {'_id': ObjectId('5e852fe3783b5294fa61603e'), 'Year': 2017, 'Month': 10, 'Day': 2, 'US Avg': 2.682}
# {'_id': ObjectId('5e852fe3783b5294fa61603f'), 'Year': 2017, 'Month': 9, 'Day': 25, 'US Avg': 2.701}
# {'_id': ObjectId('5e852fe3783b5294fa616040'), 'Year': 2017, 'Month': 9, 'Day': 18, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616041'), 'Year': 2017, 'Month': 9, 'Day': 11, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616042'), 'Year': 2017, 'Month': 9, 'Day': 4, 'US Avg': 2.794}
# {'_id': ObjectId('5e852fe3783b5294fa616043'), 'Year': 2017, 'Month': 8, 'Day': 28, 'US Avg': 2.513}
# {'_id': ObjectId('5e852fe3783b5294fa616044'), 'Year': 2017, 'Month': 8, 'Day': 21, 'US Avg': 2.474}
# {'_id': ObjectId('5e852fe3783b5294fa616045'), 'Year': 2017, 'Month': 8, 'Day': 14, 'US Avg': 2.497}
# {'_id': ObjectId('5e852fe3783b5294fa616046'), 'Year': 2017, 'Month': 8, 'Day': 7, 'US Avg': 2.492}
# {'_id': ObjectId('5e852fe3783b5294fa616047'), 'Year': 2017, 'Month': 7, 'Day': 31, 'US Avg': 2.467}
# {'_id': ObjectId('5e852fe3783b5294fa616048'), 'Year': 2017, 'Month': 7, 'Day': 24, 'US Avg': 2.426}
# {'_id': ObjectId('5e852fe3783b5294fa616049'), 'Year': 2017, 'Month': 7, 'Day': 17, 'US Avg': 2.392}
# {'_id': ObjectId('5e852fe3783b5294fa61604a'), 'Year': 2017, 'Month': 7, 'Day': 10, 'US Avg': 2.411}
# {'_id': ObjectId('5e852fe3783b5294fa61604b'), 'Year': 2017, 'Month': 7, 'Day': 3, 'US Avg': 2.376}
# {'_id': ObjectId('5e852fe3783b5294fa61604c'), 'Year': 2017, 'Month': 6, 'Day': 26, 'US Avg': 2.404}
# {'_id': ObjectId('5e852fe3783b5294fa61604d'), 'Year': 2017, 'Month': 6, 'Day': 19, 'US Avg': 2.433}
# {'_id': ObjectId('5e852fe3783b5294fa61604e'), 'Year': 2017, 'Month': 6, 'Day': 12, 'US Avg': 2.479}
# {'_id': ObjectId('5e852fe3783b5294fa61604f'), 'Year': 2017, 'Month': 6, 'Day': 5, 'US Avg': 2.525}
# {'_id': ObjectId('5e852fe3783b5294fa616050'), 'Year': 2017, 'Month': 5, 'Day': 29, 'US Avg': 2.516}
# {'_id': ObjectId('5e852fe3783b5294fa616051'), 'Year': 2017, 'Month': 5, 'Day': 22, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616052'), 'Year': 2017, 'Month': 5, 'Day': 15, 'US Avg': 2.481}
# {'_id': ObjectId('5e852fe3783b5294fa616053'), 'Year': 2017, 'Month': 5, 'Day': 8, 'US Avg': 2.484}
# {'_id': ObjectId('5e852fe3783b5294fa616054'), 'Year': 2017, 'Month': 5, 'Day': 1, 'US Avg': 2.522}
# {'_id': ObjectId('5e852fe3783b5294fa616055'), 'Year': 2017, 'Month': 4, 'Day': 24, 'US Avg': 2.559}
# {'_id': ObjectId('5e852fe3783b5294fa616056'), 'Year': 2017, 'Month': 4, 'Day': 17, 'US Avg': 2.546}
# {'_id': ObjectId('5e852fe3783b5294fa616057'), 'Year': 2017, 'Month': 4, 'Day': 10, 'US Avg': 2.534}
# {'_id': ObjectId('5e852fe3783b5294fa616058'), 'Year': 2017, 'Month': 4, 'Day': 3, 'US Avg': 2.471}
# {'_id': ObjectId('5e852fe3783b5294fa616059'), 'Year': 2017, 'Month': 3, 'Day': 27, 'US Avg': 2.428}
# {'_id': ObjectId('5e852fe3783b5294fa61605a'), 'Year': 2017, 'Month': 3, 'Day': 20, 'US Avg': 2.433}
# {'_id': ObjectId('5e852fe3783b5294fa61605b'), 'Year': 2017, 'Month': 3, 'Day': 13, 'US Avg': 2.434}
# {'_id': ObjectId('5e852fe3783b5294fa61605c'), 'Year': 2017, 'Month': 3, 'Day': 6, 'US Avg': 2.452}
# {'_id': ObjectId('5e852fe3783b5294fa61605d'), 'Year': 2017, 'Month': 2, 'Day': 27, 'US Avg': 2.427}
# {'_id': ObjectId('5e852fe3783b5294fa61605e'), 'Year': 2017, 'Month': 2, 'Day': 20, 'US Avg': 2.414}
# {'_id': ObjectId('5e852fe3783b5294fa61605f'), 'Year': 2017, 'Month': 2, 'Day': 13, 'US Avg': 2.418}
# {'_id': ObjectId('5e852fe3783b5294fa616060'), 'Year': 2017, 'Month': 2, 'Day': 6, 'US Avg': 2.405}
# {'_id': ObjectId('5e852fe3783b5294fa616061'), 'Year': 2017, 'Month': 1, 'Day': 30, 'US Avg': 2.408}
# {'_id': ObjectId('5e852fe3783b5294fa616062'), 'Year': 2017, 'Month': 1, 'Day': 23, 'US Avg': 2.436}
# {'_id': ObjectId('5e852fe3783b5294fa616063'), 'Year': 2017, 'Month': 1, 'Day': 16, 'US Avg': 2.467}
# {'_id': ObjectId('5e852fe3783b5294fa616064'), 'Year': 2017, 'Month': 1, 'Day': 9, 'US Avg': 2.496}
# {'_id': ObjectId('5e852fe3783b5294fa616065'), 'Year': 2017, 'Month': 1, 'Day': 2, 'US Avg': 2.485}
# {'_id': ObjectId('5e852fe3783b5294fa616066'), 'Year': 2016, 'Month': 12, 'Day': 26, 'US Avg': 2.419}
# {'_id': ObjectId('5e852fe3783b5294fa616067'), 'Year': 2016, 'Month': 12, 'Day': 19, 'US Avg': 2.375}
# {'_id': ObjectId('5e852fe3783b5294fa616068'), 'Year': 2016, 'Month': 12, 'Day': 12, 'US Avg': 2.347}
# {'_id': ObjectId('5e852fe3783b5294fa616069'), 'Year': 2016, 'Month': 12, 'Day': 5, 'US Avg': 2.321}
# {'_id': ObjectId('5e852fe3783b5294fa61606a'), 'Year': 2016, 'Month': 11, 'Day': 28, 'US Avg': 2.268}
# {'_id': ObjectId('5e852fe3783b5294fa61606b'), 'Year': 2016, 'Month': 11, 'Day': 21, 'US Avg': 2.269}
# {'_id': ObjectId('5e852fe3783b5294fa61606c'), 'Year': 2016, 'Month': 11, 'Day': 14, 'US Avg': 2.298}
# {'_id': ObjectId('5e852fe3783b5294fa61606d'), 'Year': 2016, 'Month': 11, 'Day': 7, 'US Avg': 2.345}
# {'_id': ObjectId('5e852fe3783b5294fa61606e'), 'Year': 2016, 'Month': 10, 'Day': 31, 'US Avg': 2.341}
# {'_id': ObjectId('5e852fe3783b5294fa61606f'), 'Year': 2016, 'Month': 10, 'Day': 24, 'US Avg': 2.353}
# {'_id': ObjectId('5e852fe3783b5294fa616070'), 'Year': 2016, 'Month': 10, 'Day': 17, 'US Avg': 2.367}
# {'_id': ObjectId('5e852fe3783b5294fa616071'), 'Year': 2016, 'Month': 10, 'Day': 10, 'US Avg': 2.381}
# {'_id': ObjectId('5e852fe3783b5294fa616072'), 'Year': 2016, 'Month': 10, 'Day': 3, 'US Avg': 2.354}
# {'_id': ObjectId('5e852fe3783b5294fa616073'), 'Year': 2016, 'Month': 9, 'Day': 26, 'US Avg': 2.334}
# {'_id': ObjectId('5e852fe3783b5294fa616074'), 'Year': 2016, 'Month': 9, 'Day': 19, 'US Avg': 2.333}
# {'_id': ObjectId('5e852fe3783b5294fa616075'), 'Year': 2016, 'Month': 9, 'Day': 12, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616076'), 'Year': 2016, 'Month': 9, 'Day': 5, 'US Avg': 2.329}
# {'_id': ObjectId('5e852fe3783b5294fa616077'), 'Year': 2016, 'Month': 8, 'Day': 29, 'US Avg': 2.341}
# {'_id': ObjectId('5e852fe3783b5294fa616078'), 'Year': 2016, 'Month': 8, 'Day': 22, 'US Avg': 2.299}
# {'_id': ObjectId('5e852fe3783b5294fa616079'), 'Year': 2016, 'Month': 8, 'Day': 15, 'US Avg': 2.256}
# {'_id': ObjectId('5e852fe3783b5294fa61607a'), 'Year': 2016, 'Month': 8, 'Day': 8, 'US Avg': 2.256}
# {'_id': ObjectId('5e852fe3783b5294fa61607b'), 'Year': 2016, 'Month': 8, 'Day': 1, 'US Avg': 2.267}
# {'_id': ObjectId('5e852fe3783b5294fa61607c'), 'Year': 2016, 'Month': 7, 'Day': 25, 'US Avg': 2.289}
# {'_id': ObjectId('5e852fe3783b5294fa61607d'), 'Year': 2016, 'Month': 7, 'Day': 18, 'US Avg': 2.336}
# {'_id': ObjectId('5e852fe3783b5294fa61607e'), 'Year': 2016, 'Month': 7, 'Day': 11, 'US Avg': 2.359}
# {'_id': ObjectId('5e852fe3783b5294fa61607f'), 'Year': 2016, 'Month': 7, 'Day': 4, 'US Avg': 2.396}
# {'_id': ObjectId('5e852fe3783b5294fa616080'), 'Year': 2016, 'Month': 6, 'Day': 27, 'US Avg': 2.432}
# {'_id': ObjectId('5e852fe3783b5294fa616081'), 'Year': 2016, 'Month': 6, 'Day': 20, 'US Avg': 2.455}
# {'_id': ObjectId('5e852fe3783b5294fa616082'), 'Year': 2016, 'Month': 6, 'Day': 13, 'US Avg': 2.499}
# {'_id': ObjectId('5e852fe3783b5294fa616083'), 'Year': 2016, 'Month': 6, 'Day': 6, 'US Avg': 2.482}
# {'_id': ObjectId('5e852fe3783b5294fa616084'), 'Year': 2016, 'Month': 5, 'Day': 30, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616085'), 'Year': 2016, 'Month': 5, 'Day': 23, 'US Avg': 2.403}
# {'_id': ObjectId('5e852fe3783b5294fa616086'), 'Year': 2016, 'Month': 5, 'Day': 16, 'US Avg': 2.345}
# {'_id': ObjectId('5e852fe3783b5294fa616087'), 'Year': 2016, 'Month': 5, 'Day': 9, 'US Avg': 2.325}
# {'_id': ObjectId('5e852fe3783b5294fa616088'), 'Year': 2016, 'Month': 5, 'Day': 2, 'US Avg': 2.342}
# {'_id': ObjectId('5e852fe3783b5294fa616089'), 'Year': 2016, 'Month': 4, 'Day': 25, 'US Avg': 2.265}
# {'_id': ObjectId('5e852fe3783b5294fa61608a'), 'Year': 2016, 'Month': 4, 'Day': 18, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa61608b'), 'Year': 2016, 'Month': 4, 'Day': 11, 'US Avg': 2.173}
# {'_id': ObjectId('5e852fe3783b5294fa61608c'), 'Year': 2016, 'Month': 4, 'Day': 4, 'US Avg': 2.185}
# {'_id': ObjectId('5e852fe3783b5294fa61608d'), 'Year': 2016, 'Month': 3, 'Day': 28, 'US Avg': 2.169}
# {'_id': ObjectId('5e852fe3783b5294fa61608e'), 'Year': 2016, 'Month': 3, 'Day': 21, 'US Avg': 2.109}
# {'_id': ObjectId('5e852fe3783b5294fa61608f'), 'Year': 2016, 'Month': 3, 'Day': 14, 'US Avg': 2.062}
# {'_id': ObjectId('5e852fe3783b5294fa616090'), 'Year': 2016, 'Month': 3, 'Day': 7, 'US Avg': 1.943}
# {'_id': ObjectId('5e852fe3783b5294fa616091'), 'Year': 2016, 'Month': 2, 'Day': 29, 'US Avg': 1.887}
# {'_id': ObjectId('5e852fe3783b5294fa616092'), 'Year': 2016, 'Month': 2, 'Day': 22, 'US Avg': 1.837}
# {'_id': ObjectId('5e852fe3783b5294fa616093'), 'Year': 2016, 'Month': 2, 'Day': 15, 'US Avg': 1.834}
# {'_id': ObjectId('5e852fe3783b5294fa616094'), 'Year': 2016, 'Month': 2, 'Day': 8, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616095'), 'Year': 2016, 'Month': 2, 'Day': 1, 'US Avg': 1.932}
# {'_id': ObjectId('5e852fe3783b5294fa616096'), 'Year': 2016, 'Month': 1, 'Day': 25, 'US Avg': 1.965}
# {'_id': ObjectId('5e852fe3783b5294fa616097'), 'Year': 2016, 'Month': 1, 'Day': 18, 'US Avg': 2.022}
# {'_id': ObjectId('5e852fe3783b5294fa616098'), 'Year': 2016, 'Month': 1, 'Day': 11, 'US Avg': 2.104}
# {'_id': ObjectId('5e852fe3783b5294fa616099'), 'Year': 2016, 'Month': 1, 'Day': 4, 'US Avg': 2.135}
# {'_id': ObjectId('5e852fe3783b5294fa61609a'), 'Year': 2015, 'Month': 12, 'Day': 28, 'US Avg': 2.141}
# {'_id': ObjectId('5e852fe3783b5294fa61609b'), 'Year': 2015, 'Month': 12, 'Day': 21, 'US Avg': 2.133}
# {'_id': ObjectId('5e852fe3783b5294fa61609c'), 'Year': 2015, 'Month': 12, 'Day': 14, 'US Avg': 2.144}
# {'_id': ObjectId('5e852fe3783b5294fa61609d'), 'Year': 2015, 'Month': 12, 'Day': 7, 'US Avg': 2.159}
# {'_id': ObjectId('5e852fe3783b5294fa61609e'), 'Year': 2015, 'Month': 11, 'Day': 30, 'US Avg': 2.165}
# {'_id': ObjectId('5e852fe3783b5294fa61609f'), 'Year': 2015, 'Month': 11, 'Day': 23, 'US Avg': 2.198}
# {'_id': ObjectId('5e852fe3783b5294fa6160a0'), 'Year': 2015, 'Month': 11, 'Day': 16, 'US Avg': 2.281}
# {'_id': ObjectId('5e852fe3783b5294fa6160a1'), 'Year': 2015, 'Month': 11, 'Day': 9, 'US Avg': 2.335}
# {'_id': ObjectId('5e852fe3783b5294fa6160a2'), 'Year': 2015, 'Month': 11, 'Day': 2, 'US Avg': 2.322}
# {'_id': ObjectId('5e852fe3783b5294fa6160a3'), 'Year': 2015, 'Month': 10, 'Day': 26, 'US Avg': 2.326}
# {'_id': ObjectId('5e852fe3783b5294fa6160a4'), 'Year': 2015, 'Month': 10, 'Day': 19, 'US Avg': 2.374}
# {'_id': ObjectId('5e852fe3783b5294fa6160a5'), 'Year': 2015, 'Month': 10, 'Day': 12, 'US Avg': 2.432}
# {'_id': ObjectId('5e852fe3783b5294fa6160a6'), 'Year': 2015, 'Month': 10, 'Day': 5, 'US Avg': 2.415}
# {'_id': ObjectId('5e852fe3783b5294fa6160a7'), 'Year': 2015, 'Month': 9, 'Day': 28, 'US Avg': 2.418}
# {'_id': ObjectId('5e852fe3783b5294fa6160a8'), 'Year': 2015, 'Month': 9, 'Day': 21, 'US Avg': 2.425}
# {'_id': ObjectId('5e852fe3783b5294fa6160a9'), 'Year': 2015, 'Month': 9, 'Day': 14, 'US Avg': 2.471}
# {'_id': ObjectId('5e852fe3783b5294fa6160aa'), 'Year': 2015, 'Month': 9, 'Day': 7, 'US Avg': 2.532}
# {'_id': ObjectId('5e852fe3783b5294fa6160ab'), 'Year': 2015, 'Month': 8, 'Day': 31, 'US Avg': 2.602}
# {'_id': ObjectId('5e852fe3783b5294fa6160ac'), 'Year': 2015, 'Month': 8, 'Day': 24, 'US Avg': 2.726}
# {'_id': ObjectId('5e852fe3783b5294fa6160ad'), 'Year': 2015, 'Month': 8, 'Day': 17, 'US Avg': 2.803}
# {'_id': ObjectId('5e852fe3783b5294fa6160ae'), 'Year': 2015, 'Month': 8, 'Day': 10, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160af'), 'Year': 2015, 'Month': 8, 'Day': 3, 'US Avg': 2.779}
# {'_id': ObjectId('5e852fe3783b5294fa6160b0'), 'Year': 2015, 'Month': 7, 'Day': 27, 'US Avg': 2.833}
# {'_id': ObjectId('5e852fe3783b5294fa6160b1'), 'Year': 2015, 'Month': 7, 'Day': 20, 'US Avg': 2.888}
# {'_id': ObjectId('5e852fe3783b5294fa6160b2'), 'Year': 2015, 'Month': 7, 'Day': 13, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160b3'), 'Year': 2015, 'Month': 7, 'Day': 6, 'US Avg': 2.877}
# {'_id': ObjectId('5e852fe3783b5294fa6160b4'), 'Year': 2015, 'Month': 6, 'Day': 29, 'US Avg': 2.885}
# {'_id': ObjectId('5e852fe3783b5294fa6160b5'), 'Year': 2015, 'Month': 6, 'Day': 22, 'US Avg': 2.895}
# {'_id': ObjectId('5e852fe3783b5294fa6160b6'), 'Year': 2015, 'Month': 6, 'Day': 15, 'US Avg': 2.918}
# {'_id': ObjectId('5e852fe3783b5294fa6160b7'), 'Year': 2015, 'Month': 6, 'Day': 8, 'US Avg': 2.863}
# {'_id': ObjectId('5e852fe3783b5294fa6160b8'), 'Year': 2015, 'Month': 6, 'Day': 1, 'US Avg': 2.863}
# {'_id': ObjectId('5e852fe3783b5294fa6160b9'), 'Year': 2015, 'Month': 5, 'Day': 25, 'US Avg': 2.857}
# {'_id': ObjectId('5e852fe3783b5294fa6160ba'), 'Year': 2015, 'Month': 5, 'Day': 18, 'US Avg': 2.827}
# {'_id': ObjectId('5e852fe3783b5294fa6160bb'), 'Year': 2015, 'Month': 5, 'Day': 11, 'US Avg': 2.776}
# {'_id': ObjectId('5e852fe3783b5294fa6160bc'), 'Year': 2015, 'Month': 5, 'Day': 4, 'US Avg': 2.749}
# {'_id': ObjectId('5e852fe3783b5294fa6160bd'), 'Year': 2015, 'Month': 4, 'Day': 27, 'US Avg': 2.656}
# {'_id': ObjectId('5e852fe3783b5294fa6160be'), 'Year': 2015, 'Month': 4, 'Day': 20, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160bf'), 'Year': 2015, 'Month': 4, 'Day': 13, 'US Avg': 2.494}
# {'_id': ObjectId('5e852fe3783b5294fa6160c0'), 'Year': 2015, 'Month': 4, 'Day': 6, 'US Avg': 2.499}
# {'_id': ObjectId('5e852fe3783b5294fa6160c1'), 'Year': 2015, 'Month': 3, 'Day': 30, 'US Avg': 2.531}
# {'_id': ObjectId('5e852fe3783b5294fa6160c2'), 'Year': 2015, 'Month': 3, 'Day': 23, 'US Avg': 2.538}
# {'_id': ObjectId('5e852fe3783b5294fa6160c3'), 'Year': 2015, 'Month': 3, 'Day': 16, 'US Avg': 2.537}
# {'_id': ObjectId('5e852fe3783b5294fa6160c4'), 'Year': 2015, 'Month': 3, 'Day': 9, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160c5'), 'Year': 2015, 'Month': 3, 'Day': 2, 'US Avg': 2.556}
# {'_id': ObjectId('5e852fe3783b5294fa6160c6'), 'Year': 2015, 'Month': 2, 'Day': 23, 'US Avg': 2.415}
# {'_id': ObjectId('5e852fe3783b5294fa6160c7'), 'Year': 2015, 'Month': 2, 'Day': 16, 'US Avg': 2.358}
# {'_id': ObjectId('5e852fe3783b5294fa6160c8'), 'Year': 2015, 'Month': 2, 'Day': 9, 'US Avg': 2.276}
# {'_id': ObjectId('5e852fe3783b5294fa6160c9'), 'Year': 2015, 'Month': 2, 'Day': 2, 'US Avg': 2.154}
# {'_id': ObjectId('5e852fe3783b5294fa6160ca'), 'Year': 2015, 'Month': 1, 'Day': 26, 'US Avg': 2.133}
# {'_id': ObjectId('5e852fe3783b5294fa6160cb'), 'Year': 2015, 'Month': 1, 'Day': 19, 'US Avg': 2.157}
# {'_id': ObjectId('5e852fe3783b5294fa6160cc'), 'Year': 2015, 'Month': 1, 'Day': 12, 'US Avg': 2.232}
# {'_id': ObjectId('5e852fe3783b5294fa6160cd'), 'Year': 2015, 'Month': 1, 'Day': 5, 'US Avg': 2.308}
# {'_id': ObjectId('5e852fe3783b5294fa6160ce'), 'Year': 2014, 'Month': 12, 'Day': 29, 'US Avg': 2.392}
# {'_id': ObjectId('5e852fe3783b5294fa6160cf'), 'Year': 2014, 'Month': 12, 'Day': 22, 'US Avg': 2.496}
# {'_id': ObjectId('5e852fe3783b5294fa6160d0'), 'Year': 2014, 'Month': 12, 'Day': 15, 'US Avg': 2.643}
# {'_id': ObjectId('5e852fe3783b5294fa6160d1'), 'Year': 2014, 'Month': 12, 'Day': 8, 'US Avg': 2.767}
# {'_id': ObjectId('5e852fe3783b5294fa6160d2'), 'Year': 2014, 'Month': 12, 'Day': 1, 'US Avg': 2.864}
# {'_id': ObjectId('5e852fe3783b5294fa6160d3'), 'Year': 2014, 'Month': 11, 'Day': 24, 'US Avg': 2.907}
# {'_id': ObjectId('5e852fe3783b5294fa6160d4'), 'Year': 2014, 'Month': 11, 'Day': 17, 'US Avg': 2.978}
# {'_id': ObjectId('5e852fe3783b5294fa6160d5'), 'Year': 2014, 'Month': 11, 'Day': 10, 'US Avg': 3.025}
# {'_id': ObjectId('5e852fe3783b5294fa6160d6'), 'Year': 2014, 'Month': 11, 'Day': 3, 'US Avg': 3.077}
# {'_id': ObjectId('5e852fe3783b5294fa6160d7'), 'Year': 2014, 'Month': 10, 'Day': 27, 'US Avg': 3.139}
# {'_id': ObjectId('5e852fe3783b5294fa6160d8'), 'Year': 2014, 'Month': 10, 'Day': 20, 'US Avg': 3.205}
# {'_id': ObjectId('5e852fe3783b5294fa6160d9'), 'Year': 2014, 'Month': 10, 'Day': 13, 'US Avg': 3.292}
# {'_id': ObjectId('5e852fe3783b5294fa6160da'), 'Year': 2014, 'Month': 10, 'Day': 6, 'US Avg': 3.382}
# {'_id': ObjectId('5e852fe3783b5294fa6160db'), 'Year': 2014, 'Month': 9, 'Day': 29, 'US Avg': 3.434}
# {'_id': ObjectId('5e852fe3783b5294fa6160dc'), 'Year': 2014, 'Month': 9, 'Day': 22, 'US Avg': 3.432}
# {'_id': ObjectId('5e852fe3783b5294fa6160dd'), 'Year': 2014, 'Month': 9, 'Day': 15, 'US Avg': 3.485}
# {'_id': ObjectId('5e852fe3783b5294fa6160de'), 'Year': 2014, 'Month': 9, 'Day': 8, 'US Avg': 3.534}
# {'_id': ObjectId('5e852fe3783b5294fa6160df'), 'Year': 2014, 'Month': 9, 'Day': 1, 'US Avg': 3.536}
# {'_id': ObjectId('5e852fe3783b5294fa6160e0'), 'Year': 2014, 'Month': 8, 'Day': 25, 'US Avg': 3.532}
# {'_id': ObjectId('5e852fe3783b5294fa6160e1'), 'Year': 2014, 'Month': 8, 'Day': 18, 'US Avg': 3.549}
# {'_id': ObjectId('5e852fe3783b5294fa6160e2'), 'Year': 2014, 'Month': 8, 'Day': 11, 'US Avg': 3.582}
# {'_id': ObjectId('5e852fe3783b5294fa6160e3'), 'Year': 2014, 'Month': 8, 'Day': 4, 'US Avg': 3.595}
# {'_id': ObjectId('5e852fe3783b5294fa6160e4'), 'Year': 2014, 'Month': 7, 'Day': 28, 'US Avg': 3.617}
# {'_id': ObjectId('5e852fe3783b5294fa6160e5'), 'Year': 2014, 'Month': 7, 'Day': 21, 'US Avg': 3.671}
# {'_id': ObjectId('5e852fe3783b5294fa6160e6'), 'Year': 2014, 'Month': 7, 'Day': 14, 'US Avg': 3.712}
# {'_id': ObjectId('5e852fe3783b5294fa6160e7'), 'Year': 2014, 'Month': 7, 'Day': 7, 'US Avg': 3.753}
# {'_id': ObjectId('5e852fe3783b5294fa6160e8'), 'Year': 2014, 'Month': 6, 'Day': 30, 'US Avg': 3.778}
# {'_id': ObjectId('5e852fe3783b5294fa6160e9'), 'Year': 2014, 'Month': 6, 'Day': 23, 'US Avg': 3.778}
# {'_id': ObjectId('5e852fe3783b5294fa6160ea'), 'Year': 2014, 'Month': 6, 'Day': 16, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160eb'), 'Year': 2014, 'Month': 6, 'Day': 9, 'US Avg': 3.749}
# {'_id': ObjectId('5e852fe3783b5294fa6160ec'), 'Year': 2014, 'Month': 6, 'Day': 2, 'US Avg': 3.765}
# {'_id': ObjectId('5e852fe3783b5294fa6160ed'), 'Year': 2014, 'Month': 5, 'Day': 26, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160ee'), 'Year': 2014, 'Month': 5, 'Day': 19, 'US Avg': 3.743}
# {'_id': ObjectId('5e852fe3783b5294fa6160ef'), 'Year': 2014, 'Month': 5, 'Day': 12, 'US Avg': 3.746}
# {'_id': ObjectId('5e852fe3783b5294fa6160f0'), 'Year': 2014, 'Month': 5, 'Day': 5, 'US Avg': 3.761}
# {'_id': ObjectId('5e852fe3783b5294fa6160f1'), 'Year': 2014, 'Month': 4, 'Day': 28, 'US Avg': 3.788}
# {'_id': ObjectId('5e852fe3783b5294fa6160f2'), 'Year': 2014, 'Month': 4, 'Day': 21, 'US Avg': 3.758}
# {'_id': ObjectId('5e852fe3783b5294fa6160f3'), 'Year': 2014, 'Month': 4, 'Day': 14, 'US Avg': 3.725}
# {'_id': ObjectId('5e852fe3783b5294fa6160f4'), 'Year': 2014, 'Month': 4, 'Day': 7, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160f5'), 'Year': 2014, 'Month': 3, 'Day': 31, 'US Avg': 3.651}
# {'_id': ObjectId('5e852fe3783b5294fa6160f6'), 'Year': 2014, 'Month': 3, 'Day': 24, 'US Avg': 3.622}
# {'_id': ObjectId('5e852fe3783b5294fa6160f7'), 'Year': 2014, 'Month': 3, 'Day': 17, 'US Avg': 3.619}
# {'_id': ObjectId('5e852fe3783b5294fa6160f8'), 'Year': 2014, 'Month': 3, 'Day': 10, 'US Avg': 3.584}
# {'_id': ObjectId('5e852fe3783b5294fa6160f9'), 'Year': 2014, 'Month': 3, 'Day': 3, 'US Avg': 3.553}
# {'_id': ObjectId('5e852fe3783b5294fa6160fa'), 'Year': 2014, 'Month': 2, 'Day': 24, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6160fb'), 'Year': 2014, 'Month': 2, 'Day': 17, 'US Avg': 3.457}
# {'_id': ObjectId('5e852fe3783b5294fa6160fc'), 'Year': 2014, 'Month': 2, 'Day': 10, 'US Avg': 3.388}
# {'_id': ObjectId('5e852fe3783b5294fa6160fd'), 'Year': 2014, 'Month': 2, 'Day': 3, 'US Avg': 3.372}
# {'_id': ObjectId('5e852fe3783b5294fa6160fe'), 'Year': 2014, 'Month': 1, 'Day': 27, 'US Avg': 3.375}
# {'_id': ObjectId('5e852fe3783b5294fa6160ff'), 'Year': 2014, 'Month': 1, 'Day': 20, 'US Avg': 3.376}
# {'_id': ObjectId('5e852fe3783b5294fa616100'), 'Year': 2014, 'Month': 1, 'Day': 13, 'US Avg': 3.406}
# {'_id': ObjectId('5e852fe3783b5294fa616101'), 'Year': 2014, 'Month': 1, 'Day': 6, 'US Avg': 3.411}
# {'_id': ObjectId('5e852fe3783b5294fa616102'), 'Year': 2013, 'Month': 12, 'Day': 30, 'US Avg': 3.409}
# {'_id': ObjectId('5e852fe3783b5294fa616103'), 'Year': 2013, 'Month': 12, 'Day': 23, 'US Avg': 3.351}
# {'_id': ObjectId('5e852fe3783b5294fa616104'), 'Year': 2013, 'Month': 12, 'Day': 16, 'US Avg': 3.321}
# {'_id': ObjectId('5e852fe3783b5294fa616105'), 'Year': 2013, 'Month': 12, 'Day': 9, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616106'), 'Year': 2013, 'Month': 12, 'Day': 2, 'US Avg': 3.353}
# {'_id': ObjectId('5e852fe3783b5294fa616107'), 'Year': 2013, 'Month': 11, 'Day': 25, 'US Avg': 3.372}
# {'_id': ObjectId('5e852fe3783b5294fa616108'), 'Year': 2013, 'Month': 11, 'Day': 18, 'US Avg': 3.298}
# {'_id': ObjectId('5e852fe3783b5294fa616109'), 'Year': 2013, 'Month': 11, 'Day': 11, 'US Avg': 3.274}
# {'_id': ObjectId('5e852fe3783b5294fa61610a'), 'Year': 2013, 'Month': 11, 'Day': 4, 'US Avg': 3.343}
# {'_id': ObjectId('5e852fe3783b5294fa61610b'), 'Year': 2013, 'Month': 10, 'Day': 28, 'US Avg': 3.372}
# {'_id': ObjectId('5e852fe3783b5294fa61610c'), 'Year': 2013, 'Month': 10, 'Day': 21, 'US Avg': 3.435}
# {'_id': ObjectId('5e852fe3783b5294fa61610d'), 'Year': 2013, 'Month': 10, 'Day': 14, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa61610e'), 'Year': 2013, 'Month': 10, 'Day': 7, 'US Avg': 3.441}
# {'_id': ObjectId('5e852fe3783b5294fa61610f'), 'Year': 2013, 'Month': 9, 'Day': 30, 'US Avg': 3.499}
# {'_id': ObjectId('5e852fe3783b5294fa616110'), 'Year': 2013, 'Month': 9, 'Day': 23, 'US Avg': 3.567}
# {'_id': ObjectId('5e852fe3783b5294fa616111'), 'Year': 2013, 'Month': 9, 'Day': 16, 'US Avg': 3.619}
# {'_id': ObjectId('5e852fe3783b5294fa616112'), 'Year': 2013, 'Month': 9, 'Day': 9, 'US Avg': 3.658}
# {'_id': ObjectId('5e852fe3783b5294fa616113'), 'Year': 2013, 'Month': 9, 'Day': 2, 'US Avg': 3.678}
# {'_id': ObjectId('5e852fe3783b5294fa616114'), 'Year': 2013, 'Month': 8, 'Day': 26, 'US Avg': 3.623}
# {'_id': ObjectId('5e852fe3783b5294fa616115'), 'Year': 2013, 'Month': 8, 'Day': 19, 'US Avg': 3.622}
# {'_id': ObjectId('5e852fe3783b5294fa616116'), 'Year': 2013, 'Month': 8, 'Day': 12, 'US Avg': 3.633}
# {'_id': ObjectId('5e852fe3783b5294fa616117'), 'Year': 2013, 'Month': 8, 'Day': 5, 'US Avg': 3.701}
# {'_id': ObjectId('5e852fe3783b5294fa616118'), 'Year': 2013, 'Month': 7, 'Day': 29, 'US Avg': 3.716}
# {'_id': ObjectId('5e852fe3783b5294fa616119'), 'Year': 2013, 'Month': 7, 'Day': 22, 'US Avg': 3.751}
# {'_id': ObjectId('5e852fe3783b5294fa61611a'), 'Year': 2013, 'Month': 7, 'Day': 15, 'US Avg': 3.706}
# {'_id': ObjectId('5e852fe3783b5294fa61611b'), 'Year': 2013, 'Month': 7, 'Day': 8, 'US Avg': 3.563}
# {'_id': ObjectId('5e852fe3783b5294fa61611c'), 'Year': 2013, 'Month': 7, 'Day': 1, 'US Avg': 3.567}
# {'_id': ObjectId('5e852fe3783b5294fa61611d'), 'Year': 2013, 'Month': 6, 'Day': 24, 'US Avg': 3.645}
# {'_id': ObjectId('5e852fe3783b5294fa61611e'), 'Year': 2013, 'Month': 6, 'Day': 17, 'US Avg': 3.689}
# {'_id': ObjectId('5e852fe3783b5294fa61611f'), 'Year': 2013, 'Month': 6, 'Day': 10, 'US Avg': 3.715}
# {'_id': ObjectId('5e852fe3783b5294fa616120'), 'Year': 2013, 'Month': 6, 'Day': 3, 'US Avg': 3.705}
# {'_id': ObjectId('5e852fe3783b5294fa616121'), 'Year': 2013, 'Month': 5, 'Day': 27, 'US Avg': 3.704}
# {'_id': ObjectId('5e852fe3783b5294fa616122'), 'Year': 2013, 'Month': 5, 'Day': 20, 'US Avg': 3.729}
# {'_id': ObjectId('5e852fe3783b5294fa616123'), 'Year': 2013, 'Month': 5, 'Day': 13, 'US Avg': 3.665}
# {'_id': ObjectId('5e852fe3783b5294fa616124'), 'Year': 2013, 'Month': 5, 'Day': 6, 'US Avg': 3.602}
# {'_id': ObjectId('5e852fe3783b5294fa616125'), 'Year': 2013, 'Month': 4, 'Day': 29, 'US Avg': 3.587}
# {'_id': ObjectId('5e852fe3783b5294fa616126'), 'Year': 2013, 'Month': 4, 'Day': 22, 'US Avg': 3.603}
# {'_id': ObjectId('5e852fe3783b5294fa616127'), 'Year': 2013, 'Month': 4, 'Day': 15, 'US Avg': 3.611}
# {'_id': ObjectId('5e852fe3783b5294fa616128'), 'Year': 2013, 'Month': 4, 'Day': 8, 'US Avg': 3.676}
# {'_id': ObjectId('5e852fe3783b5294fa616129'), 'Year': 2013, 'Month': 4, 'Day': 1, 'US Avg': 3.714}
# {'_id': ObjectId('5e852fe3783b5294fa61612a'), 'Year': 2013, 'Month': 3, 'Day': 25, 'US Avg': 3.746}
# {'_id': ObjectId('5e852fe3783b5294fa61612b'), 'Year': 2013, 'Month': 3, 'Day': 18, 'US Avg': 3.764}
# {'_id': ObjectId('5e852fe3783b5294fa61612c'), 'Year': 2013, 'Month': 3, 'Day': 11, 'US Avg': 3.779}
# {'_id': ObjectId('5e852fe3783b5294fa61612d'), 'Year': 2013, 'Month': 3, 'Day': 4, 'US Avg': 3.826}
# {'_id': ObjectId('5e852fe3783b5294fa61612e'), 'Year': 2013, 'Month': 2, 'Day': 25, 'US Avg': 3.851}
# {'_id': ObjectId('5e852fe3783b5294fa61612f'), 'Year': 2013, 'Month': 2, 'Day': 18, 'US Avg': 3.812}
# {'_id': ObjectId('5e852fe3783b5294fa616130'), 'Year': 2013, 'Month': 2, 'Day': 11, 'US Avg': 3.677}
# {'_id': ObjectId('5e852fe3783b5294fa616131'), 'Year': 2013, 'Month': 2, 'Day': 4, 'US Avg': 3.604}
# {'_id': ObjectId('5e852fe3783b5294fa616132'), 'Year': 2013, 'Month': 1, 'Day': 28, 'US Avg': 3.427}
# {'_id': ObjectId('5e852fe3783b5294fa616133'), 'Year': 2013, 'Month': 1, 'Day': 21, 'US Avg': 3.386}
# {'_id': ObjectId('5e852fe3783b5294fa616134'), 'Year': 2013, 'Month': 1, 'Day': 14, 'US Avg': 3.377}
# {'_id': ObjectId('5e852fe3783b5294fa616135'), 'Year': 2013, 'Month': 1, 'Day': 7, 'US Avg': 3.373}
# {'_id': ObjectId('5e852fe3783b5294fa616136'), 'Year': 2012, 'Month': 12, 'Day': 31, 'US Avg': 3.369}
# {'_id': ObjectId('5e852fe3783b5294fa616137'), 'Year': 2012, 'Month': 12, 'Day': 24, 'US Avg': 3.328}
# {'_id': ObjectId('5e852fe3783b5294fa616138'), 'Year': 2012, 'Month': 12, 'Day': 17, 'US Avg': 3.324}
# {'_id': ObjectId('5e852fe3783b5294fa616139'), 'Year': 2012, 'Month': 12, 'Day': 10, 'US Avg': 3.419}
# {'_id': ObjectId('5e852fe3783b5294fa61613a'), 'Year': 2012, 'Month': 12, 'Day': 3, 'US Avg': 3.463}
# {'_id': ObjectId('5e852fe3783b5294fa61613b'), 'Year': 2012, 'Month': 11, 'Day': 26, 'US Avg': 3.505}
# {'_id': ObjectId('5e852fe3783b5294fa61613c'), 'Year': 2012, 'Month': 11, 'Day': 19, 'US Avg': 3.497}
# {'_id': ObjectId('5e852fe3783b5294fa61613d'), 'Year': 2012, 'Month': 11, 'Day': 12, 'US Avg': 3.518}
# {'_id': ObjectId('5e852fe3783b5294fa61613e'), 'Year': 2012, 'Month': 11, 'Day': 5, 'US Avg': 3.563}
# {'_id': ObjectId('5e852fe3783b5294fa61613f'), 'Year': 2012, 'Month': 10, 'Day': 29, 'US Avg': 3.638}
# {'_id': ObjectId('5e852fe3783b5294fa616140'), 'Year': 2012, 'Month': 10, 'Day': 22, 'US Avg': 3.756}
# {'_id': ObjectId('5e852fe3783b5294fa616141'), 'Year': 2012, 'Month': 10, 'Day': 15, 'US Avg': 3.886}
# {'_id': ObjectId('5e852fe3783b5294fa616142'), 'Year': 2012, 'Month': 10, 'Day': 8, 'US Avg': 3.914}
# {'_id': ObjectId('5e852fe3783b5294fa616143'), 'Year': 2012, 'Month': 10, 'Day': 1, 'US Avg': 3.866}
# {'_id': ObjectId('5e852fe3783b5294fa616144'), 'Year': 2012, 'Month': 9, 'Day': 24, 'US Avg': 3.889}
# {'_id': ObjectId('5e852fe3783b5294fa616145'), 'Year': 2012, 'Month': 9, 'Day': 17, 'US Avg': 3.939}
# {'_id': ObjectId('5e852fe3783b5294fa616146'), 'Year': 2012, 'Month': 9, 'Day': 10, 'US Avg': 3.907}
# {'_id': ObjectId('5e852fe3783b5294fa616147'), 'Year': 2012, 'Month': 9, 'Day': 3, 'US Avg': 3.903}
# {'_id': ObjectId('5e852fe3783b5294fa616148'), 'Year': 2012, 'Month': 8, 'Day': 27, 'US Avg': 3.837}
# {'_id': ObjectId('5e852fe3783b5294fa616149'), 'Year': 2012, 'Month': 8, 'Day': 20, 'US Avg': 3.803}
# {'_id': ObjectId('5e852fe3783b5294fa61614a'), 'Year': 2012, 'Month': 8, 'Day': 13, 'US Avg': 3.779}
# {'_id': ObjectId('5e852fe3783b5294fa61614b'), 'Year': 2012, 'Month': 8, 'Day': 6, 'US Avg': 3.702}
# {'_id': ObjectId('5e852fe3783b5294fa61614c'), 'Year': 2012, 'Month': 7, 'Day': 30, 'US Avg': 3.568}
# {'_id': ObjectId('5e852fe3783b5294fa61614d'), 'Year': 2012, 'Month': 7, 'Day': 23, 'US Avg': 3.554}
# {'_id': ObjectId('5e852fe3783b5294fa61614e'), 'Year': 2012, 'Month': 7, 'Day': 16, 'US Avg': 3.485}
# {'_id': ObjectId('5e852fe3783b5294fa61614f'), 'Year': 2012, 'Month': 7, 'Day': 9, 'US Avg': 3.469}
# {'_id': ObjectId('5e852fe3783b5294fa616150'), 'Year': 2012, 'Month': 7, 'Day': 2, 'US Avg': 3.415}
# {'_id': ObjectId('5e852fe3783b5294fa616151'), 'Year': 2012, 'Month': 6, 'Day': 25, 'US Avg': 3.494}
# {'_id': ObjectId('5e852fe3783b5294fa616152'), 'Year': 2012, 'Month': 6, 'Day': 18, 'US Avg': 3.589}
# {'_id': ObjectId('5e852fe3783b5294fa616153'), 'Year': 2012, 'Month': 6, 'Day': 11, 'US Avg': 3.629}
# {'_id': ObjectId('5e852fe3783b5294fa616154'), 'Year': 2012, 'Month': 6, 'Day': 4, 'US Avg': 3.671}
# {'_id': ObjectId('5e852fe3783b5294fa616155'), 'Year': 2012, 'Month': 5, 'Day': 28, 'US Avg': 3.728}
# {'_id': ObjectId('5e852fe3783b5294fa616156'), 'Year': 2012, 'Month': 5, 'Day': 21, 'US Avg': 3.773}
# {'_id': ObjectId('5e852fe3783b5294fa616157'), 'Year': 2012, 'Month': 5, 'Day': 14, 'US Avg': 3.814}
# {'_id': ObjectId('5e852fe3783b5294fa616158'), 'Year': 2012, 'Month': 5, 'Day': 7, 'US Avg': 3.849}
# {'_id': ObjectId('5e852fe3783b5294fa616159'), 'Year': 2012, 'Month': 4, 'Day': 30, 'US Avg': 3.889}
# {'_id': ObjectId('5e852fe3783b5294fa61615a'), 'Year': 2012, 'Month': 4, 'Day': 23, 'US Avg': 3.929}
# {'_id': ObjectId('5e852fe3783b5294fa61615b'), 'Year': 2012, 'Month': 4, 'Day': 16, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa61615c'), 'Year': 2012, 'Month': 4, 'Day': 9, 'US Avg': 3.997}
# {'_id': ObjectId('5e852fe3783b5294fa61615d'), 'Year': 2012, 'Month': 4, 'Day': 2, 'US Avg': 3.996}
# {'_id': ObjectId('5e852fe3783b5294fa61615e'), 'Year': 2012, 'Month': 3, 'Day': 26, 'US Avg': 3.973}
# {'_id': ObjectId('5e852fe3783b5294fa61615f'), 'Year': 2012, 'Month': 3, 'Day': 19, 'US Avg': 3.923}
# {'_id': ObjectId('5e852fe3783b5294fa616160'), 'Year': 2012, 'Month': 3, 'Day': 12, 'US Avg': 3.884}
# {'_id': ObjectId('5e852fe3783b5294fa616161'), 'Year': 2012, 'Month': 3, 'Day': 5, 'US Avg': 3.849}
# {'_id': ObjectId('5e852fe3783b5294fa616162'), 'Year': 2012, 'Month': 2, 'Day': 27, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616163'), 'Year': 2012, 'Month': 2, 'Day': 20, 'US Avg': 3.652}
# {'_id': ObjectId('5e852fe3783b5294fa616164'), 'Year': 2012, 'Month': 2, 'Day': 13, 'US Avg': 3.584}
# {'_id': ObjectId('5e852fe3783b5294fa616165'), 'Year': 2012, 'Month': 2, 'Day': 6, 'US Avg': 3.542}
# {'_id': ObjectId('5e852fe3783b5294fa616166'), 'Year': 2012, 'Month': 1, 'Day': 30, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616167'), 'Year': 2012, 'Month': 1, 'Day': 23, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616168'), 'Year': 2012, 'Month': 1, 'Day': 16, 'US Avg': 3.451}
# {'_id': ObjectId('5e852fe3783b5294fa616169'), 'Year': 2012, 'Month': 1, 'Day': 9, 'US Avg': 3.441}
# {'_id': ObjectId('5e852fe3783b5294fa61616a'), 'Year': 2012, 'Month': 1, 'Day': 2, 'US Avg': 3.358}
# {'_id': ObjectId('5e852fe3783b5294fa61616b'), 'Year': 2011, 'Month': 12, 'Day': 26, 'US Avg': 3.317}
# {'_id': ObjectId('5e852fe3783b5294fa61616c'), 'Year': 2011, 'Month': 12, 'Day': 19, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa61616d'), 'Year': 2011, 'Month': 12, 'Day': 12, 'US Avg': 3.346}
# {'_id': ObjectId('5e852fe3783b5294fa61616e'), 'Year': 2011, 'Month': 12, 'Day': 5, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa61616f'), 'Year': 2011, 'Month': 11, 'Day': 28, 'US Avg': 3.368}
# {'_id': ObjectId('5e852fe3783b5294fa616170'), 'Year': 2011, 'Month': 11, 'Day': 21, 'US Avg': 3.427}
# {'_id': ObjectId('5e852fe3783b5294fa616171'), 'Year': 2011, 'Month': 11, 'Day': 14, 'US Avg': 3.495}
# {'_id': ObjectId('5e852fe3783b5294fa616172'), 'Year': 2011, 'Month': 11, 'Day': 7, 'US Avg': 3.482}
# {'_id': ObjectId('5e852fe3783b5294fa616173'), 'Year': 2011, 'Month': 10, 'Day': 31, 'US Avg': 3.511}
# {'_id': ObjectId('5e852fe3783b5294fa616174'), 'Year': 2011, 'Month': 10, 'Day': 24, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616175'), 'Year': 2011, 'Month': 10, 'Day': 17, 'US Avg': 3.533}
# {'_id': ObjectId('5e852fe3783b5294fa616176'), 'Year': 2011, 'Month': 10, 'Day': 10, 'US Avg': 3.476}
# {'_id': ObjectId('5e852fe3783b5294fa616177'), 'Year': 2011, 'Month': 10, 'Day': 3, 'US Avg': 3.492}
# {'_id': ObjectId('5e852fe3783b5294fa616178'), 'Year': 2011, 'Month': 9, 'Day': 26, 'US Avg': 3.568}
# {'_id': ObjectId('5e852fe3783b5294fa616179'), 'Year': 2011, 'Month': 9, 'Day': 19, 'US Avg': 3.657}
# {'_id': ObjectId('5e852fe3783b5294fa61617a'), 'Year': 2011, 'Month': 9, 'Day': 12, 'US Avg': 3.715}
# {'_id': ObjectId('5e852fe3783b5294fa61617b'), 'Year': 2011, 'Month': 9, 'Day': 5, 'US Avg': 3.727}
# {'_id': ObjectId('5e852fe3783b5294fa61617c'), 'Year': 2011, 'Month': 8, 'Day': 29, 'US Avg': 3.682}
# {'_id': ObjectId('5e852fe3783b5294fa61617d'), 'Year': 2011, 'Month': 8, 'Day': 22, 'US Avg': 3.638}
# {'_id': ObjectId('5e852fe3783b5294fa61617e'), 'Year': 2011, 'Month': 8, 'Day': 15, 'US Avg': 3.662}
# {'_id': ObjectId('5e852fe3783b5294fa61617f'), 'Year': 2011, 'Month': 8, 'Day': 8, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616180'), 'Year': 2011, 'Month': 8, 'Day': 1, 'US Avg': 3.766}
# {'_id': ObjectId('5e852fe3783b5294fa616181'), 'Year': 2011, 'Month': 7, 'Day': 25, 'US Avg': 3.754}
# {'_id': ObjectId('5e852fe3783b5294fa616182'), 'Year': 2011, 'Month': 7, 'Day': 18, 'US Avg': 3.736}
# {'_id': ObjectId('5e852fe3783b5294fa616183'), 'Year': 2011, 'Month': 7, 'Day': 11, 'US Avg': 3.695}
# {'_id': ObjectId('5e852fe3783b5294fa616184'), 'Year': 2011, 'Month': 7, 'Day': 4, 'US Avg': 3.634}
# {'_id': ObjectId('5e852fe3783b5294fa616185'), 'Year': 2011, 'Month': 6, 'Day': 27, 'US Avg': 3.631}
# {'_id': ObjectId('5e852fe3783b5294fa616186'), 'Year': 2011, 'Month': 6, 'Day': 20, 'US Avg': 3.708}
# {'_id': ObjectId('5e852fe3783b5294fa616187'), 'Year': 2011, 'Month': 6, 'Day': 13, 'US Avg': 3.767}
# {'_id': ObjectId('5e852fe3783b5294fa616188'), 'Year': 2011, 'Month': 6, 'Day': 6, 'US Avg': 3.833}
# {'_id': ObjectId('5e852fe3783b5294fa616189'), 'Year': 2011, 'Month': 5, 'Day': 30, 'US Avg': 3.848}
# {'_id': ObjectId('5e852fe3783b5294fa61618a'), 'Year': 2011, 'Month': 5, 'Day': 23, 'US Avg': 3.904}
# {'_id': ObjectId('5e852fe3783b5294fa61618b'), 'Year': 2011, 'Month': 5, 'Day': 16, 'US Avg': 4.014}
# {'_id': ObjectId('5e852fe3783b5294fa61618c'), 'Year': 2011, 'Month': 5, 'Day': 9, 'US Avg': 4.018}
# {'_id': ObjectId('5e852fe3783b5294fa61618d'), 'Year': 2011, 'Month': 5, 'Day': 2, 'US Avg': 4.014}
# {'_id': ObjectId('5e852fe3783b5294fa61618e'), 'Year': 2011, 'Month': 4, 'Day': 25, 'US Avg': 3.932}
# {'_id': ObjectId('5e852fe3783b5294fa61618f'), 'Year': 2011, 'Month': 4, 'Day': 18, 'US Avg': 3.896}
# {'_id': ObjectId('5e852fe3783b5294fa616190'), 'Year': 2011, 'Month': 4, 'Day': 11, 'US Avg': 3.843}
# {'_id': ObjectId('5e852fe3783b5294fa616191'), 'Year': 2011, 'Month': 4, 'Day': 4, 'US Avg': 3.737}
# {'_id': ObjectId('5e852fe3783b5294fa616192'), 'Year': 2011, 'Month': 3, 'Day': 28, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616193'), 'Year': 2011, 'Month': 3, 'Day': 21, 'US Avg': 3.617}
# {'_id': ObjectId('5e852fe3783b5294fa616194'), 'Year': 2011, 'Month': 3, 'Day': 14, 'US Avg': 3.621}
# {'_id': ObjectId('5e852fe3783b5294fa616195'), 'Year': 2011, 'Month': 3, 'Day': 7, 'US Avg': 3.572}
# {'_id': ObjectId('5e852fe3783b5294fa616196'), 'Year': 2011, 'Month': 2, 'Day': 28, 'US Avg': 3.435}
# {'_id': ObjectId('5e852fe3783b5294fa616197'), 'Year': 2011, 'Month': 2, 'Day': 21, 'US Avg': 3.243}
# {'_id': ObjectId('5e852fe3783b5294fa616198'), 'Year': 2011, 'Month': 2, 'Day': 14, 'US Avg': 3.193}
# {'_id': ObjectId('5e852fe3783b5294fa616199'), 'Year': 2011, 'Month': 2, 'Day': 7, 'US Avg': 3.185}
# {'_id': ObjectId('5e852fe3783b5294fa61619a'), 'Year': 2011, 'Month': 1, 'Day': 31, 'US Avg': 3.155}
# {'_id': ObjectId('5e852fe3783b5294fa61619b'), 'Year': 2011, 'Month': 1, 'Day': 24, 'US Avg': 3.163}
# {'_id': ObjectId('5e852fe3783b5294fa61619c'), 'Year': 2011, 'Month': 1, 'Day': 17, 'US Avg': 3.158}
# {'_id': ObjectId('5e852fe3783b5294fa61619d'), 'Year': 2011, 'Month': 1, 'Day': 10, 'US Avg': 3.142}
# {'_id': ObjectId('5e852fe3783b5294fa61619e'), 'Year': 2011, 'Month': 1, 'Day': 3, 'US Avg': 3.124}
# {'_id': ObjectId('5e852fe3783b5294fa61619f'), 'Year': 2010, 'Month': 12, 'Day': 27, 'US Avg': 3.106}
# ...
# {'_id': ObjectId('5e852fe3783b5294fa61649d'), 'Year': 1996, 'Month': 4, 'Day': 22, 'US Avg': 1.301}
# {'_id': ObjectId('5e852fe3783b5294fa61649e'), 'Year': 1996, 'Month': 4, 'Day': 15, 'US Avg': 1.287}
# {'_id': ObjectId('5e852fe3783b5294fa61649f'), 'Year': 1996, 'Month': 4, 'Day': 8, 'US Avg': 1.248}
# {'_id': ObjectId('5e852fe3783b5294fa6164a0'), 'Year': 1996, 'Month': 4, 'Day': 1, 'US Avg': 1.223}
# {'_id': ObjectId('5e852fe3783b5294fa6164a1'), 'Year': 1996, 'Month': 3, 'Day': 25, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164a2'), 'Year': 1996, 'Month': 3, 'Day': 18, 'US Avg': 1.181}
# {'_id': ObjectId('5e852fe3783b5294fa6164a3'), 'Year': 1996, 'Month': 3, 'Day': 11, 'US Avg': 1.171}
# {'_id': ObjectId('5e852fe3783b5294fa6164a4'), 'Year': 1996, 'Month': 3, 'Day': 4, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164a5'), 'Year': 1996, 'Month': 2, 'Day': 26, 'US Avg': 1.153}
# {'_id': ObjectId('5e852fe3783b5294fa6164a6'), 'Year': 1996, 'Month': 2, 'Day': 19, 'US Avg': 1.133}
# {'_id': ObjectId('5e852fe3783b5294fa6164a7'), 'Year': 1996, 'Month': 2, 'Day': 12, 'US Avg': 1.126}
# {'_id': ObjectId('5e852fe3783b5294fa6164a8'), 'Year': 1996, 'Month': 2, 'Day': 5, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164a9'), 'Year': 1996, 'Month': 1, 'Day': 29, 'US Avg': 1.133}
# {'_id': ObjectId('5e852fe3783b5294fa6164aa'), 'Year': 1996, 'Month': 1, 'Day': 22, 'US Avg': 1.138}
# {'_id': ObjectId('5e852fe3783b5294fa6164ab'), 'Year': 1996, 'Month': 1, 'Day': 15, 'US Avg': 1.145}
# {'_id': ObjectId('5e852fe3783b5294fa6164ac'), 'Year': 1996, 'Month': 1, 'Day': 8, 'US Avg': 1.139}
# {'_id': ObjectId('5e852fe3783b5294fa6164ad'), 'Year': 1996, 'Month': 1, 'Day': 1, 'US Avg': 1.129}
# {'_id': ObjectId('5e852fe3783b5294fa6164ae'), 'Year': 1995, 'Month': 12, 'Day': 25, 'US Avg': 1.128}
# {'_id': ObjectId('5e852fe3783b5294fa6164af'), 'Year': 1995, 'Month': 12, 'Day': 18, 'US Avg': 1.124}
# {'_id': ObjectId('5e852fe3783b5294fa6164b0'), 'Year': 1995, 'Month': 12, 'Day': 11, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164b1'), 'Year': 1995, 'Month': 12, 'Day': 4, 'US Avg': 1.108}
# {'_id': ObjectId('5e852fe3783b5294fa6164b2'), 'Year': 1995, 'Month': 11, 'Day': 27, 'US Avg': 1.107}
# {'_id': ObjectId('5e852fe3783b5294fa6164b3'), 'Year': 1995, 'Month': 11, 'Day': 20, 'US Avg': 1.106}
# {'_id': ObjectId('5e852fe3783b5294fa6164b4'), 'Year': 1995, 'Month': 11, 'Day': 13, 'US Avg': 1.109}
# {'_id': ObjectId('5e852fe3783b5294fa6164b5'), 'Year': 1995, 'Month': 11, 'Day': 6, 'US Avg': 1.112}
# {'_id': ObjectId('5e852fe3783b5294fa6164b6'), 'Year': 1995, 'Month': 10, 'Day': 30, 'US Avg': 1.115}
# {'_id': ObjectId('5e852fe3783b5294fa6164b7'), 'Year': 1995, 'Month': 10, 'Day': 23, 'US Avg': 1.125}
# {'_id': ObjectId('5e852fe3783b5294fa6164b8'), 'Year': 1995, 'Month': 10, 'Day': 16, 'US Avg': 1.133}
# {'_id': ObjectId('5e852fe3783b5294fa6164b9'), 'Year': 1995, 'Month': 10, 'Day': 9, 'US Avg': 1.144}
# {'_id': ObjectId('5e852fe3783b5294fa6164ba'), 'Year': 1995, 'Month': 10, 'Day': 2, 'US Avg': 1.151}
# {'_id': ObjectId('5e852fe3783b5294fa6164bb'), 'Year': 1995, 'Month': 9, 'Day': 25, 'US Avg': 1.156}
# {'_id': ObjectId('5e852fe3783b5294fa6164bc'), 'Year': 1995, 'Month': 9, 'Day': 18, 'US Avg': 1.157}
# {'_id': ObjectId('5e852fe3783b5294fa6164bd'), 'Year': 1995, 'Month': 9, 'Day': 11, 'US Avg': 1.158}
# {'_id': ObjectId('5e852fe3783b5294fa6164be'), 'Year': 1995, 'Month': 9, 'Day': 4, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164bf'), 'Year': 1995, 'Month': 8, 'Day': 28, 'US Avg': 1.163}
# {'_id': ObjectId('5e852fe3783b5294fa6164c0'), 'Year': 1995, 'Month': 8, 'Day': 21, 'US Avg': 1.171}
# {'_id': ObjectId('5e852fe3783b5294fa6164c1'), 'Year': 1995, 'Month': 8, 'Day': 14, 'US Avg': 1.172}
# {'_id': ObjectId('5e852fe3783b5294fa6164c2'), 'Year': 1995, 'Month': 8, 'Day': 7, 'US Avg': 1.174}
# {'_id': ObjectId('5e852fe3783b5294fa6164c3'), 'Year': 1995, 'Month': 7, 'Day': 31, 'US Avg': 1.179}
# {'_id': ObjectId('5e852fe3783b5294fa6164c4'), 'Year': 1995, 'Month': 7, 'Day': 24, 'US Avg': 1.191}
# {'_id': ObjectId('5e852fe3783b5294fa6164c5'), 'Year': 1995, 'Month': 7, 'Day': 17, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164c6'), 'Year': 1995, 'Month': 7, 'Day': 10, 'US Avg': 1.212}
# {'_id': ObjectId('5e852fe3783b5294fa6164c7'), 'Year': 1995, 'Month': 7, 'Day': 3, 'US Avg': 1.222}
# {'_id': ObjectId('5e852fe3783b5294fa6164c8'), 'Year': 1995, 'Month': 6, 'Day': 26, 'US Avg': 1.229}
# {'_id': ObjectId('5e852fe3783b5294fa6164c9'), 'Year': 1995, 'Month': 6, 'Day': 19, 'US Avg': 1.236}
# {'_id': ObjectId('5e852fe3783b5294fa6164ca'), 'Year': 1995, 'Month': 6, 'Day': 12, 'US Avg': 1.243}
# {'_id': ObjectId('5e852fe3783b5294fa6164cb'), 'Year': 1995, 'Month': 6, 'Day': 5, 'US Avg': 1.246}
# {'_id': ObjectId('5e852fe3783b5294fa6164cc'), 'Year': 1995, 'Month': 5, 'Day': 29, 'US Avg': 1.246}
# {'_id': ObjectId('5e852fe3783b5294fa6164cd'), 'Year': 1995, 'Month': 5, 'Day': 22, 'US Avg': 1.244}
# {'_id': ObjectId('5e852fe3783b5294fa6164ce'), 'Year': 1995, 'Month': 5, 'Day': 15, 'US Avg': 1.226}
# {'_id': ObjectId('5e852fe3783b5294fa6164cf'), 'Year': 1995, 'Month': 5, 'Day': 8, 'US Avg': 1.216}
# {'_id': ObjectId('5e852fe3783b5294fa6164d0'), 'Year': 1995, 'Month': 5, 'Day': 1, 'US Avg': 1.194}
# {'_id': ObjectId('5e852fe3783b5294fa6164d1'), 'Year': 1995, 'Month': 4, 'Day': 24, 'US Avg': 1.184}
# {'_id': ObjectId('5e852fe3783b5294fa6164d2'), 'Year': 1995, 'Month': 4, 'Day': 17, 'US Avg': 1.163}
# {'_id': ObjectId('5e852fe3783b5294fa6164d3'), 'Year': 1995, 'Month': 4, 'Day': 10, 'US Avg': 1.149}
# {'_id': ObjectId('5e852fe3783b5294fa6164d4'), 'Year': 1995, 'Month': 4, 'Day': 3, 'US Avg': 1.133}
# {'_id': ObjectId('5e852fe3783b5294fa6164d5'), 'Year': 1995, 'Month': 3, 'Day': 27, 'US Avg': 1.121}
# {'_id': ObjectId('5e852fe3783b5294fa6164d6'), 'Year': 1995, 'Month': 3, 'Day': 20, 'US Avg': 1.114}
# {'_id': ObjectId('5e852fe3783b5294fa6164d7'), 'Year': 1995, 'Month': 3, 'Day': 13, 'US Avg': 1.116}
# {'_id': ObjectId('5e852fe3783b5294fa6164d8'), 'Year': 1995, 'Month': 3, 'Day': 6, 'US Avg': 1.123}
# {'_id': ObjectId('5e852fe3783b5294fa6164d9'), 'Year': 1995, 'Month': 2, 'Day': 27, 'US Avg': 1.121}
# {'_id': ObjectId('5e852fe3783b5294fa6164da'), 'Year': 1995, 'Month': 2, 'Day': 20, 'US Avg': 1.115}
# {'_id': ObjectId('5e852fe3783b5294fa6164db'), 'Year': 1995, 'Month': 2, 'Day': 13, 'US Avg': 1.121}
# {'_id': ObjectId('5e852fe3783b5294fa6164dc'), 'Year': 1995, 'Month': 2, 'Day': 6, 'US Avg': 1.124}
# {'_id': ObjectId('5e852fe3783b5294fa6164dd'), 'Year': 1995, 'Month': 1, 'Day': 30, 'US Avg': 1.131}
# {'_id': ObjectId('5e852fe3783b5294fa6164de'), 'Year': 1995, 'Month': 1, 'Day': 23, 'US Avg': 1.132}
# {'_id': ObjectId('5e852fe3783b5294fa6164df'), 'Year': 1995, 'Month': 1, 'Day': 16, 'US Avg': 1.126}
# {'_id': ObjectId('5e852fe3783b5294fa6164e0'), 'Year': 1995, 'Month': 1, 'Day': 9, 'US Avg': 1.134}
# {'_id': ObjectId('5e852fe3783b5294fa6164e1'), 'Year': 1995, 'Month': 1, 'Day': 2, 'US Avg': 1.127}
# {'_id': ObjectId('5e852fe3783b5294fa6164e2'), 'Year': 1994, 'Month': 12, 'Day': 26, 'US Avg': 1.125}
# {'_id': ObjectId('5e852fe3783b5294fa6164e3'), 'Year': 1994, 'Month': 12, 'Day': 19, 'US Avg': 1.134}
# {'_id': ObjectId('5e852fe3783b5294fa6164e4'), 'Year': 1994, 'Month': 12, 'Day': 12, 'US Avg': 1.131}
# {'_id': ObjectId('5e852fe3783b5294fa6164e5'), 'Year': 1994, 'Month': 12, 'Day': 5, 'US Avg': 1.127}
# {'_id': ObjectId('5e852fe3783b5294fa6164e6'), 'Year': 1994, 'Month': 11, 'Day': 28, 'US Avg': 1.117}
# {'_id': ObjectId('5e852fe3783b5294fa6164e7'), 'Year': 1994, 'Month': 11, 'Day': 21, 'US Avg': 1.113}
# {'_id': ObjectId('5e852fe3783b5294fa6164e8'), 'Year': 1994, 'Month': 11, 'Day': 14, 'US Avg': 1.122}
# {'_id': ObjectId('5e852fe3783b5294fa6164e9'), 'Year': 1994, 'Month': 11, 'Day': 7, 'US Avg': 1.123}
# {'_id': ObjectId('5e852fe3783b5294fa6164ea'), 'Year': 1994, 'Month': 10, 'Day': 31, 'US Avg': 1.121}
# {'_id': ObjectId('5e852fe3783b5294fa6164eb'), 'Year': 1994, 'Month': 10, 'Day': 24, 'US Avg': 1.107}
# {'_id': ObjectId('5e852fe3783b5294fa6164ec'), 'Year': 1994, 'Month': 10, 'Day': 17, 'US Avg': 1.106}
# {'_id': ObjectId('5e852fe3783b5294fa6164ed'), 'Year': 1994, 'Month': 10, 'Day': 10, 'US Avg': 1.114}
# {'_id': ObjectId('5e852fe3783b5294fa6164ee'), 'Year': 1994, 'Month': 10, 'Day': 3, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164ef'), 'Year': 1994, 'Month': 9, 'Day': 26, 'US Avg': 1.129}
# {'_id': ObjectId('5e852fe3783b5294fa6164f0'), 'Year': 1994, 'Month': 9, 'Day': 19, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164f1'), 'Year': 1994, 'Month': 9, 'Day': 12, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164f2'), 'Year': 1994, 'Month': 9, 'Day': 5, 'US Avg': 1.156}
# {'_id': ObjectId('5e852fe3783b5294fa6164f3'), 'Year': 1994, 'Month': 8, 'Day': 29, 'US Avg': 1.161}
# {'_id': ObjectId('5e852fe3783b5294fa6164f4'), 'Year': 1994, 'Month': 8, 'Day': 22, 'US Avg': 1.165}
# {'_id': ObjectId('5e852fe3783b5294fa6164f5'), 'Year': 1994, 'Month': 8, 'Day': 15, 'US Avg': 1.161}
# {'_id': ObjectId('5e852fe3783b5294fa6164f6'), 'Year': 1994, 'Month': 8, 'Day': 8, 'US Avg': 1.157}
# {'_id': ObjectId('5e852fe3783b5294fa6164f7'), 'Year': 1994, 'Month': 8, 'Day': 1, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa6164f8'), 'Year': 1994, 'Month': 7, 'Day': 25, 'US Avg': 1.114}
# {'_id': ObjectId('5e852fe3783b5294fa6164f9'), 'Year': 1994, 'Month': 7, 'Day': 18, 'US Avg': 1.109}
# {'_id': ObjectId('5e852fe3783b5294fa6164fa'), 'Year': 1994, 'Month': 7, 'Day': 11, 'US Avg': 1.103}
# {'_id': ObjectId('5e852fe3783b5294fa6164fb'), 'Year': 1994, 'Month': 7, 'Day': 4, 'US Avg': 1.097}
# {'_id': ObjectId('5e852fe3783b5294fa6164fc'), 'Year': 1994, 'Month': 6, 'Day': 27, 'US Avg': 1.095}
# {'_id': ObjectId('5e852fe3783b5294fa6164fd'), 'Year': 1994, 'Month': 6, 'Day': 20, 'US Avg': 1.079}
# {'_id': ObjectId('5e852fe3783b5294fa6164fe'), 'Year': 1994, 'Month': 6, 'Day': 13, 'US Avg': 1.073}
# {'_id': ObjectId('5e852fe3783b5294fa6164ff'), 'Year': 1994, 'Month': 6, 'Day': 6, 'US Avg': 1.065}
# {'_id': ObjectId('5e852fe3783b5294fa616500'), 'Year': 1994, 'Month': 5, 'Day': 30, 'US Avg': 1.056}
# {'_id': ObjectId('5e852fe3783b5294fa616501'), 'Year': 1994, 'Month': 5, 'Day': 23, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616502'), 'Year': 1994, 'Month': 5, 'Day': 16, 'US Avg': 1.046}
# {'_id': ObjectId('5e852fe3783b5294fa616503'), 'Year': 1994, 'Month': 5, 'Day': 9, 'US Avg': 1.045}
# {'_id': ObjectId('5e852fe3783b5294fa616504'), 'Year': 1994, 'Month': 5, 'Day': 2, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616505'), 'Year': 1994, 'Month': 4, 'Day': 25, 'US Avg': 1.037}
# {'_id': ObjectId('5e852fe3783b5294fa616506'), 'Year': 1994, 'Month': 4, 'Day': 18, 'US Avg': 1.033}
# {'_id': ObjectId('5e852fe3783b5294fa616507'), 'Year': 1994, 'Month': 4, 'Day': 11, 'US Avg': 1.028}
# {'_id': ObjectId('5e852fe3783b5294fa616508'), 'Year': 1994, 'Month': 4, 'Day': 4, 'US Avg': 1.011}
# {'_id': ObjectId('5e852fe3783b5294fa616509'), 'Year': 1994, 'Month': 3, 'Day': 28, 'US Avg': 1.012}
# {'_id': ObjectId('5e852fe3783b5294fa61650a'), 'Year': 1994, 'Month': 3, 'Day': 21, 'US Avg': 1.007}
# {'_id': ObjectId('5e852fe3783b5294fa61650b'), 'Year': 1994, 'Month': 3, 'Day': 14, 'US Avg': 1.005}
# {'_id': ObjectId('5e852fe3783b5294fa61650c'), 'Year': 1994, 'Month': 3, 'Day': 7, 'US Avg': 1.007}
# {'_id': ObjectId('5e852fe3783b5294fa61650d'), 'Year': 1994, 'Month': 2, 'Day': 28, 'US Avg': 1.004}
# {'_id': ObjectId('5e852fe3783b5294fa61650e'), 'Year': 1994, 'Month': 2, 'Day': 21, 'US Avg': 1.009}
# {'_id': ObjectId('5e852fe3783b5294fa61650f'), 'Year': 1994, 'Month': 2, 'Day': 14, 'US Avg': 1.016}
# {'_id': ObjectId('5e852fe3783b5294fa616510'), 'Year': 1994, 'Month': 2, 'Day': 7, 'US Avg': 1.007}
# {'_id': ObjectId('5e852fe3783b5294fa616511'), 'Year': 1994, 'Month': 1, 'Day': 31, 'US Avg': 1.005}
# {'_id': ObjectId('5e852fe3783b5294fa616512'), 'Year': 1994, 'Month': 1, 'Day': 24, 'US Avg': 0.999}
# {'_id': ObjectId('5e852fe3783b5294fa616513'), 'Year': 1994, 'Month': 1, 'Day': 17, 'US Avg': 1.001}
# {'_id': ObjectId('5e852fe3783b5294fa616514'), 'Year': 1994, 'Month': 1, 'Day': 10, 'US Avg': 0.995}
# {'_id': ObjectId('5e852fe3783b5294fa616515'), 'Year': 1994, 'Month': 1, 'Day': 3, 'US Avg': 0.992}
# {'_id': ObjectId('5e852fe3783b5294fa616516'), 'Year': 1993, 'Month': 12, 'Day': 27, 'US Avg': 0.999}
# {'_id': ObjectId('5e852fe3783b5294fa616517'), 'Year': 1993, 'Month': 12, 'Day': 20, 'US Avg': 1.003}
# {'_id': ObjectId('5e852fe3783b5294fa616518'), 'Year': 1993, 'Month': 12, 'Day': 13, 'US Avg': 1.018}
# {'_id': ObjectId('5e852fe3783b5294fa616519'), 'Year': 1993, 'Month': 12, 'Day': 6, 'US Avg': 1.036}
# {'_id': ObjectId('5e852fe3783b5294fa61651a'), 'Year': 1993, 'Month': 11, 'Day': 29, 'US Avg': 1.051}
# {'_id': ObjectId('5e852fe3783b5294fa61651b'), 'Year': 1993, 'Month': 11, 'Day': 22, 'US Avg': 1.058}
# {'_id': ObjectId('5e852fe3783b5294fa61651c'), 'Year': 1993, 'Month': 11, 'Day': 15, 'US Avg': 1.064}
# {'_id': ObjectId('5e852fe3783b5294fa61651d'), 'Year': 1993, 'Month': 11, 'Day': 8, 'US Avg': 1.075}
# {'_id': ObjectId('5e852fe3783b5294fa61651e'), 'Year': 1993, 'Month': 11, 'Day': 1, 'US Avg': 1.084}
# {'_id': ObjectId('5e852fe3783b5294fa61651f'), 'Year': 1993, 'Month': 10, 'Day': 25, 'US Avg': 1.092}
# {'_id': ObjectId('5e852fe3783b5294fa616520'), 'Year': 1993, 'Month': 10, 'Day': 18, 'US Avg': 1.093}
# {'_id': ObjectId('5e852fe3783b5294fa616521'), 'Year': 1993, 'Month': 10, 'Day': 11, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa616522'), 'Year': 1993, 'Month': 10, 'Day': 4, 'US Avg': 1.092}
# {'_id': ObjectId('5e852fe3783b5294fa616523'), 'Year': 1993, 'Month': 9, 'Day': 27, 'US Avg': 1.047}
# {'_id': ObjectId('5e852fe3783b5294fa616524'), 'Year': 1993, 'Month': 9, 'Day': 20, 'US Avg': 1.045}
# {'_id': ObjectId('5e852fe3783b5294fa616525'), 'Year': 1993, 'Month': 9, 'Day': 13, 'US Avg': 1.051}
# {'_id': ObjectId('5e852fe3783b5294fa616526'), 'Year': 1993, 'Month': 9, 'Day': 6, 'US Avg': 1.055}
# {'_id': ObjectId('5e852fe3783b5294fa616527'), 'Year': 1993, 'Month': 8, 'Day': 30, 'US Avg': 1.062}
# {'_id': ObjectId('5e852fe3783b5294fa616528'), 'Year': 1993, 'Month': 8, 'Day': 23, 'US Avg': 1.065}
# {'_id': ObjectId('5e852fe3783b5294fa616529'), 'Year': 1993, 'Month': 8, 'Day': 16, 'US Avg': 1.059}
# {'_id': ObjectId('5e852fe3783b5294fa61652a'), 'Year': 1993, 'Month': 8, 'Day': 9, 'US Avg': nan}
# {'_id': ObjectId('5e852fe3783b5294fa61652b'), 'Year': 1993, 'Month': 8, 'Day': 2, 'US Avg': 1.062}
# {'_id': ObjectId('5e852fe3783b5294fa61652c'), 'Year': 1993, 'Month': 7, 'Day': 26, 'US Avg': 1.069}
# {'_id': ObjectId('5e852fe3783b5294fa61652d'), 'Year': 1993, 'Month': 7, 'Day': 19, 'US Avg': 1.075}
# {'_id': ObjectId('5e852fe3783b5294fa61652e'), 'Year': 1993, 'Month': 7, 'Day': 12, 'US Avg': 1.081}
# {'_id': ObjectId('5e852fe3783b5294fa61652f'), 'Year': 1993, 'Month': 7, 'Day': 5, 'US Avg': 1.086}
# {'_id': ObjectId('5e852fe3783b5294fa616530'), 'Year': 1993, 'Month': 6, 'Day': 28, 'US Avg': 1.089}
# {'_id': ObjectId('5e852fe3783b5294fa616531'), 'Year': 1993, 'Month': 6, 'Day': 21, 'US Avg': 1.095}
# {'_id': ObjectId('5e852fe3783b5294fa616532'), 'Year': 1993, 'Month': 6, 'Day': 14, 'US Avg': 1.101}
# {'_id': ObjectId('5e852fe3783b5294fa616533'), 'Year': 1993, 'Month': 6, 'Day': 7, 'US Avg': 1.104}
# {'_id': ObjectId('5e852fe3783b5294fa616534'), 'Year': 1993, 'Month': 5, 'Day': 31, 'US Avg': 1.107}
# {'_id': ObjectId('5e852fe3783b5294fa616535'), 'Year': 1993, 'Month': 5, 'Day': 24, 'US Avg': 1.106}
# {'_id': ObjectId('5e852fe3783b5294fa616536'), 'Year': 1993, 'Month': 5, 'Day': 17, 'US Avg': 1.106}
# {'_id': ObjectId('5e852fe3783b5294fa616537'), 'Year': 1993, 'Month': 5, 'Day': 10, 'US Avg': 1.097}
# {'_id': ObjectId('5e852fe3783b5294fa616538'), 'Year': 1993, 'Month': 5, 'Day': 3, 'US Avg': 1.086}
# {'_id': ObjectId('5e852fe3783b5294fa616539'), 'Year': 1993, 'Month': 4, 'Day': 26, 'US Avg': 1.086}
# {'_id': ObjectId('5e852fe3783b5294fa61653a'), 'Year': 1993, 'Month': 4, 'Day': 19, 'US Avg': 1.079}
# {'_id': ObjectId('5e852fe3783b5294fa61653b'), 'Year': 1993, 'Month': 4, 'Day': 12, 'US Avg': 1.079}
# {'_id': ObjectId('5e852fe3783b5294fa61653c'), 'Year': 1993, 'Month': 4, 'Day': 5, 'US Avg': nan}

# %%
post
# Out:
# {'Year': 2000,
#  'Month': 5,
#  'CA Avg': nan,
#  '_id': ObjectId('5e852df1783b5294fa614b80')}
